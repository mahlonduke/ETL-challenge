# %% [markdown]
# # Setup

# %%
# Import dependencies
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
from splinter import Browser
from bs4 import BeautifulSoup
from flask import Flask, jsonify

# %%
# Configure browser for scraping

# Windows
executable_path = {'executable_path': 'chromedriver.exe'}

# Mac
# executable_path = {‘executable_path’: ‘/usr/local/bin/chromedriver’}

# All OS
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Define URL variables
coffeeBeanCorralURL = 'https://www.coffeebeancorral.com/categories/Green-Coffee-Beans/All-Coffees.aspx'
freshRoastedCoffeeURL = 'https://www.freshroastedcoffee.com/collections/green-coffee'
amazonURL = 'https://www.amazon.com/Best-Sellers-Grocery-Gourmet-Food-Unroasted-Coffee-Beans/zgbs/grocery/979887011'
deansBeansURL = 'https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans.html'

# %% [markdown]
# # Scrape Coffee Bean Corral for:
# - Name (listing title)
# - Price (listing price)
# - Star Rating (Number of stars given, out of five.)
# - Source (Coffee Bean Corral)
# - URL (link to the bean's individual page)

# %%
# Launch the browser
browser.visit(coffeeBeanCorralURL)

# %%
# Pull in browser content to form the soup
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Narrow the search scope to the product container
results = soup.find_all('div', class_='product-info')
print(results)

# %%
# Loop through all of the results to find the correct data
names = []
prices = []
ratings = []
URLs = []
sources = []


for result in results:
    # Name
    try:
        result_name = result.find('a').text
        print(result_name)
        names.append(result_name)
    except:
        print("Name failed")
        names.append("Failed")
        
    # Prices
    try:
        result_price = result.find('span', class_='PriceLabel').text
        print(result_price)
        prices.append(result_price)
        
    except:
        print("Price failed")
        prices.append("Failed")
        
    # Ratings
    try:
        result_rating = result.find('img')["alt"]
        print(result_rating)
        ratings.append(result_rating)
    
    except:
        print("Rating failed")
        ratings.append("Failed")
        
    # URL
    try:
        baseURL = 'https://www.coffeebeancorral.com'
        result_URL = result.find('a')
        completeURL = baseURL + result_URL["href"]
        print(completeURL)
        URLs.append(completeURL)
    
    except:
        print("URL failed")
        URLs.append("Failed")
        
    # Source
    try:
        sources.append("Coffee Bean Corral")
    
    except:
        print("Source failed")
        sources.append("Failed")

# %%
# Pull lists into a data frame
coffeeCorralData = {'Name': names, 
                   'Price': prices,
                   'Rating': ratings,
                   'URL': URLs,
                   'Source': sources}
coffeeCorral = pd.DataFrame(data=coffeeCorralData)
coffeeCorral.head()

# %%
# Remove dollar sign from Price
coffeeCorral['Price'] = coffeeCorral['Price'].str.replace('$', '')
coffeeCorral.head()

# %%
# Remove extra words from the Rating column
coffeeCorral['Rating'] = [x.split(' ')[0] for x in coffeeCorral['Rating']]
coffeeCorral.head()

# %% [markdown]
# # Scrape Amazon for:
# - Name (listing title)
# - Price (listing price)
# - Star Rating (Number of stars given, out of five.)
# - Source (Amazon)
# - URL (link to the bean's individual page)

# %%
# Launch the browser
browser.visit(amazonURL)

# %%
# Pull in browser content to form the soup
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Narrow the search scope to the product container
results = soup.find_all('span', class_='aok-inline-block zg-item')
print(results)
# Out:
# [<span class="aok-inline-block zg-item"><a class="a-link-normal" href="/Single-Unroasted-Coffee-Specialty-Nicaraguan/dp/B014THN4OI/ref=zg_bs_979887011_1?_encoding=UTF8&amp;psc=1&amp;refRID=T3VPA8FXEE08K6FDK7J9"><span class="zg-text-center-align"><div class="a-section a-spacing-small"><img alt="3 Lbs, Single Origin Unroasted Green Coffee Beans, Specialty Grade From Single Nicaraguan Estate, Direct Trade" height="200" src="https://images-na.ssl-images-amazon.com/images/I/913XLW8BLKL._AC_UL200_SR200,200_.jpg" width="200"/></div></span>
# <div aria-hidden="true" class="p13n-sc-truncate p13n-sc-line-clamp-2" data-rows="2">
#             3 Lbs, Single Origin Unroasted Green Coffee Beans, Specialty Grade From Single Nicaraguan Estate, Direct Trade
#         </div>
# </a>
# <div class="a-icon-row a-spacing-none">
# <a class="a-link-normal" href="/product-reviews/B014THN4OI/ref=zg_bs_979887011_cr_1?ie=UTF8&amp;refRID=T3VPA8FXEE08K6FDK7J9" title="4.5 out of 5 stars">
# <i class="a-icon a-icon-star a-star-4-5"><span class="a-icon-alt">4.5 out of 5 stars</span></i>
# </a>
# <a class="a-size-small a-link-normal" href="/product-reviews/B014THN4OI/ref=zg_bs_979887011_cr_1?ie=UTF8&amp;refRID=T3VPA8FXEE08K6FDK7J9">519</a>
# </div>
# <div class="a-row"><a class="a-link-normal a-text-normal" href="/Single-Unroasted-Coffee-Specialty-Nicaraguan/dp/B014THN4OI/ref=zg_bs_979887011_1?_encoding=UTF8&amp;psc=1&amp;refRID=T3VPA8FXEE08K6FDK7J9"><span class="a-size-base a-color-price"><span class="p13n-sc-price">$19.99</span></span></a> <span style="position: relative; top: 2px;"><i aria-label="Prime" class="a-icon a-icon-prime a-icon-small" role="img"></i></span></div></span>, <span class="aok-inline-block zg-item"><a class="a-link-normal" href="/Unroasted-Green-Coffee-Bean-Sampler/dp/B07RMKVJ24/ref=zg_bs_979887011_2?_encoding=UTF8&amp;psc=1&amp;refRID=T3VPA8FXEE08K6FDK7J9"><span class="zg-text-center-align"><div class="a-section a-spacing-small"><img alt="Unroasted Green Coffee Bean Sampler Pack - 4LBS - 100% raw arabica coffee beans - COLOMBIA, ETHIOPIA, GUATEMALA, COSTA RICA, BRAZIL" height="200" src="https://images-na.ssl-images-amazon.com/images/I/91omHoTN1BL._AC_UL200_SR200,200_.jpg" width="200"/></div></span>
# <div aria-hidden="true" class="p13n-sc-truncate p13n-sc-line-clamp-2" data-rows="2">
#             Unroasted Green Coffee Bean Sampler Pack - 4LBS - 100% raw arabica coffee beans - COLOMBIA, ETHIOPIA, GUATEMALA, COSTA RICA, BRAZIL
#         </div>
# </a>
# <div class="a-icon-row a-spacing-none">
# <a class="a-link-normal" href="/product-reviews/B07RMKVJ24/ref=zg_bs_979887011_cr_2?ie=UTF8&amp;refRID=T3VPA8FXEE08K6FDK7J9" title="5.0 out of 5 stars">
# <i class="a-icon a-icon-star a-star-5"><span class="a-icon-alt">5.0 out of 5 stars</span></i>
# </a>
# <a class="a-size-small a-link-normal" href="/product-reviews/B07RMKVJ24/ref=zg_bs_979887011_cr_2?ie=UTF8&amp;refRID=T3VPA8FXEE08K6FDK7J9">17</a>
# </div>
# <div class="a-row"><a class="a-link-normal a-text-normal" href="/Unroasted-Green-Coffee-Bean-Sampler/dp/B07RMKVJ24/ref=zg_bs_979887011_2?_encoding=UTF8&amp;psc=1&amp;refRID=T3VPA8FXEE08K6FDK7J9"><span class="a-size-base a-color-price"><span class="p13n-sc-price">$34.99</span></span></a> <span style="position: relative; top: 2px;"><i aria-label="Prime" class="a-icon a-icon-prime a-icon-small" role="img"></i></span></div></span>, <span class="aok-inline-block zg-item"><a class="a-link-normal" href="/COLOMBIAN-SUPREMO-Unroasted-Coffee-Arabica/dp/B0792L8BDV/ref=zg_bs_979887011_3?_encoding=UTF8&amp;psc=1&amp;refRID=T3VPA8FXEE08K6FDK7J9"><span class="zg-text-center-align"><div class="a-section a-spacing-small"><img alt="COLOMBIAN SUPREMO Unroasted Green Raw Coffee Beans, 5 LB Bulk Bag, 100% Arabica Top Grade Extra Large" height="200" src="https://images-na.ssl-images-amazon.com/images/I/41FgNBfHwQL._AC_UL200_SR200,200_.jpg" width="200"/></div></span>
# <div aria-hidden="true" class="p13n-sc-truncate p13n-sc-line-clamp-2" data-rows="2">
#             COLOMBIAN SUPREMO Unroasted Green Raw Coffee Beans,
a>
# </div>
# <div class="a-row"><a class="a-link-normal a-text-normal" href="/Diesel-Coffee-Company-Cerrado-Unroasted/dp/B07FFVLCZN/ref=zg_bs_979887011_50?_encoding=UTF8&amp;psc=1&amp;refRID=T3VPA8FXEE08K6FDK7J9"><span class="a-size-base a-color-price"><span class="p13n-sc-price">$19.75</span></span></a> <span style="position: relative; top: 2px;"><i aria-label="Prime" class="a-icon a-icon-prime a-icon-small" role="img"></i></span></div></span>]

# %%
# Loop through all of the results to find the correct data
names = []
prices = []
ratings = []
URLs = []
sources = []


for result in results:
    # Name
    try:
        resultsLevel1 = result.find('a', class_='a-link-normal')
        resultsLevel2 = resultsLevel1.find('span', class_='zg-text-center-align')
        resultsLevel3 = resultsLevel2.find('div', class_='a-section a-spacing-small')
        resultsLevel4 = resultsLevel3.find('img')
        results_name = resultsLevel4["alt"]
        print(results_name)
        names.append(results_name)
    except:
        print("Name failed")
        names.append("Failed")
        
    # Price
    try:
        priceResults = result.find('span', class_='p13n-sc-price').text
        print(priceResults)
        prices.append(priceResults)  
    except:
        print("Price failed")
        prices.append("Failed")
        
    # URL
    baseURL = 'https://amazon.com'
    try:
        resultsLink = result.find('a', class_='a-link-normal')
        resultsLink = resultsLevel1['href']
        resultsLink = baseURL + resultsLink
        print(resultsLink)
        URLs.append(resultsLink)
    except:
        print("Failed")
        URLs.append("Failed")
        
    # Source
    try:
        sources.append("Amazon Grocery")
    
    except:
        print("Source failed")
        sources.append("Failed")
        
    # Ratings
    try:
        resultsLevel1 = result.find('div', class_='a-icon-row a-spacing-none')
        result_rating = resultsLevel1.find('a')["title"]
        print(result_rating)
        ratings.append(result_rating)
    
    except:
        print("Rating failed")
        ratings.append("Failed")
# Out:
# 3 Lbs, Single Origin Unroasted Green Coffee Beans, Specialty Grade From Single Nicaraguan Estate, Direct Trade
# $19.99
# https://amazon.com/Single-Unroasted-Coffee-Specialty-Nicaraguan/dp/B014THN4OI/ref=zg_bs_979887011_1?_encoding=UTF8&psc=1&refRID=T3VPA8FXEE08K6FDK7J9
# 4.5 out of 5 stars
# Unroasted Green Coffee Bean Sampler Pack - 4LBS - 100% raw arabica coffee beans - COLOMBIA, ETHIOPIA, GUATEMALA, COSTA RICA, BRAZIL
# $34.99
# https://amazon.com/Unroasted-Green-Coffee-Bean-Sampler/dp/B07RMKVJ24/ref=zg_bs_979887011_2?_encoding=UTF8&psc=1&refRID=T3VPA8FXEE08K6FDK7J9
# 5.0 out of 5 stars
# COLOMBIAN SUPREMO Unroasted Green Raw Coffee Beans, 5 LB Bulk Bag, 100% Arabica Top Grade Extra Large
# $29.79
# https://amazon.com/COLOMBIAN-SUPREMO-Unroasted-Coffee-Arabica/dp/B0792L8BDV/ref=zg_bs_979887011_3?_encoding=UTF8&psc=1&refRID=T3VPA8FXEE08K6FDK7J9
# 4.4 out of 5 stars
# 3 Lb, Single Origin Unroasted Green Coffee Beans, Specialty Grade From Single Nicaraguan Estate, Direct Trade (Variety Pack)
# $21.49
# https://amazon.com/Unroasted-Coffee-Specialty-Nicaraguan-Variety/dp/B01MSS6DCD/ref=zg_bs_979887011_4?_encoding=UTF8&psc=1&refRID=T3VPA8FXEE08K6FDK7J9
# 4.5 out of 5 stars
# Costa Rica Dota Estate, Green Unroasted Coffee Beans, 3 lb
# $23.95
# https://amazon.com/Costa-Estate-Green-Unroasted-Coffee/dp/B00EN75754/ref=zg_bs_979887011_5?_encoding=UTF8&psc=1&refRID=T3VPA8FXEE08K6FDK7J9
# 4.2 out of 5 stars
# Anthony's Organic Unroasted Whole Green Coffee Beans, 2lbs, Mexican Altura Arabica Beans, Raw, Batch Tested and Gluten Free
# $14.99
# https://amazon.com/Anthonys-Organic-Unroasted-Mexican-Arabica/dp/B07N4C4PSB/ref=zg_bs_979887011_6?_encoding=UTF8&psc=1&refRID=T3VPA8FXEE08K6FDK7J9
# 4.1 out of 5 stars
# Green Unroasted Coffee Beans, 5 LB. Bag, Fresh Roasted Coffee LLC. (Colombian Supremo)
# $30.95
# https://amazon.com/Roasted-LLC-Unroasted-Colombian-Supremo/dp/B00E7UMXN6/ref=zg_bs_979887011_7?_encoding=UTF8&psc=1&refRID=T3VPA8FXEE08K6FDK7J9
# 3.9 out of 5 stars
# Ethiopian Yirgacheffe Green Unroasted Coffee Beans 1 Pound
# $12.97
# https://amazon.com/Ethiopian-Yirgacheffe-Green-Unroasted-Coffee/dp/B0129X141Y/ref=zg_bs_979887011_8?_encoding=UTF8&psc=1&refRID=T3VPA8FXEE08K6FDK7J9
# 4.1 out of 5 stars
# Costa Rica Dota Estate, Green Unroasted Coffee Beans, 1lb
# $9.95
# https://amazon.com/Costa-Estate-Green-Unroasted-Coffee/dp/B00EN74TBM/ref=zg_bs_979887011_9?_encoding=UTF8&psc=1&refRID=T3VPA8FXEE08K6FDK7J9
# 4.2 out of 5 stars
# Green Unroasted Coffee Beans, 5 LB. Bag, Fresh Roasted Coffee LLC. (Brazilian Cerrado)
# $27.99
# https://amazon.com/Roasted-LLC-Unroasted-Brazilian-Cerrado/dp/B00DJA51D4/ref=zg_bs_979887011_10?_encoding=UTF8&psc=1&refRID=T3VPA8FXEE08K6FDK7J9
# 4.1 out of 5 stars
# Brazil Adrano Volcano Coffee, Green Unroasted Coffee Beans (10 LB)
# Price failed
# https://amazon.com/Brazil-Adrano-Volcano-Coffee-Unroasted/dp/B00UCGABQ0/ref=zg_bs_979887011_11?_encoding=UTF8&psc=1&refRID=T3VPA8FXEE08K6FDK7J9
# 4
= {'Name': names, 
                   'Price': prices,
                   'Rating': ratings,
                   'URL': URLs,
                   'Source': sources}
amazon = pd.DataFrame(data=amazonData)
amazon.head()
# Out:
#                                                 Name   Price  \
# 0  3 Lbs, Single Origin Unroasted Green Coffee Be...  $19.99
# 1  Unroasted Green Coffee Bean Sampler Pack - 4LB...  $34.99
# 2  COLOMBIAN SUPREMO Unroasted Green Raw Coffee B...  $29.79
# 3  3 Lb, Single Origin Unroasted Green Coffee Bea...  $21.49
# 4  Costa Rica Dota Estate, Green Unroasted Coffee...  $23.95
#
#                Rating                                                URL  \
# 0  4.5 out of 5 stars  https://amazon.com/Single-Unroasted-Coffee-Spe...
# 1  5.0 out of 5 stars  https://amazon.com/Unroasted-Green-Coffee-Bean...
# 2  4.4 out of 5 stars  https://amazon.com/COLOMBIAN-SUPREMO-Unroasted...
# 3  4.5 out of 5 stars  https://amazon.com/Unroasted-Coffee-Specialty-...
# 4  4.2 out of 5 stars  https://amazon.com/Costa-Estate-Green-Unroaste...
#
#            Source
# 0  Amazon Grocery
# 1  Amazon Grocery
# 2  Amazon Grocery
# 3  Amazon Grocery
# 4  Amazon Grocery

# %%
# Remove dollar sign from Price
amazon['Price'] = amazon['Price'].str.replace('$', '')
amazon.head()
# Out:
#                                                 Name  Price  \
# 0  3 Lbs, Single Origin Unroasted Green Coffee Be...  19.99
# 1  Unroasted Green Coffee Bean Sampler Pack - 4LB...  34.99
# 2  COLOMBIAN SUPREMO Unroasted Green Raw Coffee B...  29.79
# 3  3 Lb, Single Origin Unroasted Green Coffee Bea...  21.49
# 4  Costa Rica Dota Estate, Green Unroasted Coffee...  23.95
#
#                Rating                                                URL  \
# 0  4.5 out of 5 stars  https://amazon.com/Single-Unroasted-Coffee-Spe...
# 1  5.0 out of 5 stars  https://amazon.com/Unroasted-Green-Coffee-Bean...
# 2  4.4 out of 5 stars  https://amazon.com/COLOMBIAN-SUPREMO-Unroasted...
# 3  4.5 out of 5 stars  https://amazon.com/Unroasted-Coffee-Specialty-...
# 4  4.2 out of 5 stars  https://amazon.com/Costa-Estate-Green-Unroaste...
#
#            Source
# 0  Amazon Grocery
# 1  Amazon Grocery
# 2  Amazon Grocery
# 3  Amazon Grocery
# 4  Amazon Grocery

# %%
# Remove extra words from the Rating column
amazon['Rating'] = [x.split(' ')[0] for x in amazon['Rating']]
amazon.head()
# Out:
#                                                 Name  Price Rating  \
# 0  3 Lbs, Single Origin Unroasted Green Coffee Be...  19.99    4.5
# 1  Unroasted Green Coffee Bean Sampler Pack - 4LB...  34.99    5.0
# 2  COLOMBIAN SUPREMO Unroasted Green Raw Coffee B...  29.79    4.4
# 3  3 Lb, Single Origin Unroasted Green Coffee Bea...  21.49    4.5
# 4  Costa Rica Dota Estate, Green Unroasted Coffee...  23.95    4.2
#
#                                                  URL          Source
# 0  https://amazon.com/Single-Unroasted-Coffee-Spe...  Amazon Grocery
# 1  https://amazon.com/Unroasted-Green-Coffee-Bean...  Amazon Grocery
# 2  https://amazon.com/COLOMBIAN-SUPREMO-Unroasted...  Amazon Grocery
# 3  https://amazon.com/Unroasted-Coffee-Specialty-...  Amazon Grocery
# 4  https://amazon.com/Costa-Estate-Green-Unroaste...  Amazon Grocery

# %% [markdown]
# # Scrape Dean's Beans for:
# - Name (listing title)
# - Price (listing price)
# - Star Rating (Number of stars given, out of five.)
# - Source (Amazon)
# - URL (link to the bean's individual page)

# %%
# Launch the browser
browser.visit(deansBeansURL)

# %%
# Pull in browser content to form the soup
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Narrow the search scope to the product container
results = soup.find_all('div', class_='item-content')
print(results)
# Out:
# [<div class="item-content"><h2 class="item-name"><a href="https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/kraft-paper-bags-with-tin-tie.html" title="10 Pack of Kraft Paper Bags (with Tin Tie)">10 Pack of Kraft Paper Bags (with Tin Tie)</a></h2><div class="item-desc"><a href="https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/kraft-paper-bags-with-tin-tie.html" title="10 Pack of Kraft Paper Bags (with Tin Tie)"><p>10 bags for $2.50</p></a></div><div class="item-link"> <button class="buy-link btn-go" data-id="3236">Buy now</button></div></div>, <div class="item-content"><h2 class="item-name"><a href="https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/green-bean-unroasted-coffee-sampler.html" title="Green Bean (Unroasted) Sampler Pack">Green Bean (Unroasted) Sampler Pack</a></h2><div class="item-desc"><a href="https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/green-bean-unroasted-coffee-sampler.html" title="Green Bean (Unroasted) Sampler Pack"><h5>Six 8-oz bags of assorted</h5><h5>raw green beans $18.99<span style="color: #ff0000;"><br/></span></h5></a></div><div class="item-link"> <button class="buy-link btn-go" data-id="3407">Buy now</button></div></div>, <div class="item-content"><h2 class="item-name"><a href="https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/home-roasting-green-bean-sampler-kit.html" title="Home Roasting Kit">Home Roasting Kit</a></h2><div class="item-desc"><a href="https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/home-roasting-green-bean-sampler-kit.html" title="Home Roasting Kit"><h5>$189.99<span style="color: #ff0000;"><br/></span></h5><h5>Great gift set for a</h5><h5>new home roaster!</h5></a></div><div class="item-link"> <button class="buy-link btn-go" data-id="3406">Buy now</button></div></div>, <div class="item-content"><h2 class="item-name"><a href="https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-colombian-green-coffee-unroasted.html" title="Organic Colombian Green Coffee (Unroasted)">Organic Colombian Green Coffee (Unroasted)</a></h2><div class="item-desc"><a href="https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-colombian-green-coffee-unroasted.html" title="Organic Colombian Green Coffee (Unroasted)"><h5>1lb - $5.50</h5><h5>5lb - $26.50</h5></a></div><div class="ratings"> <a href="https://deansbeans.com/review/product/list/id/3017/category/79/#customer-reviews" title="2 Review(s)"> <svg aria-label="5 out of 5 stars" role="img" version="1.1" viewbox="0 0 120 22" width="80" xmlns="http://www.w3.org/2000/svg"><title>5 out of 5 stars</title> <rect clip-path="url(#rating-clip)" fill="#635044" height="22" width="120"></rect> <use href="#rating-stars" stroke="#635044"></use> </svg> </a></div><div class="item-link"> <button class="buy-link btn-go" data-id="3017">Buy now</button></div></div>, <div class="item-content"><h2 class="item-name"><a href="https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-ethiopian-yirgacheffe-green-coffee-unroasted.html" title="Organic Ethiopian Green Coffee (Unroasted)">Organic Ethiopian Green Coffee (Unroasted)</a></h2><div class="item-desc"><a href="https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-ethiopian-yirgacheffe-green-coffee-unroasted.html" title="Organic Ethiopian Green Coffee (Unroasted)"><h5>1lb - $5.85</h5><h5>5lb - $28.25</h5></a></div><div class="ratings"> <a href="https://deansbeans.com/review/product/list/id/3020/category/79/#customer-reviews" title="2 Review(s)"> <svg aria-label="5 out of 5 stars" role="img" version="1.1" viewbox="0 0 120 22" width="80" xmlns="http://www.w3.org/2000/svg"><title>5 out of 5 stars</title> <rect clip-path="url(#rating-clip)" fill="#635044" height="22" width="120"></rect> <use href="#rating-sta ...

# %%
for result in results:
    try:
        resultsLevel1 = result.find('div', class_='item-desc')
        resultsLevel2 = resultsLevel1.find('a')
        resultsLevel3 = resultsLevel2.find('h5')
        results_price = resultsLevel3.text
        print(results_price)
        prices.append(results_price)
    except:
        print("Failed")
# Out:
# Failed
# Six 8-oz bags of assorted
# $189.99
# 1lb - $5.50
# 1lb - $5.85
# 1lb - $5.85
# 1lb - $5.85
# 1lb - $5.85
# 1lb - $6.50
# 1lb - $5.50
# 1lb - $5.50
# 1lb - $5.85

# %%
# Loop through all of the results to find the correct data
names = []
prices = []
ratings = []
URLs = []
sources = []


for result in results:
    # Name
    try:
        resultsLevel1 = result.find('h2', class_='item-name')
        resultsLevel2 = resultsLevel1.find('a')
        results_name = resultsLevel2["title"]
        print(results_name)
        names.append(results_name)
    except:
        print("Name failed")
        names.append("Failed")
        
    # Price
    try:
        resultsLevel1 = result.find('div', class_='item-desc')
        resultsLevel2 = resultsLevel1.find('a')
        resultsLevel3 = resultsLevel2.find('h5')
        results_price = resultsLevel3.text
        print(results_price)
        prices.append(results_price)
    except:
        print("Price failed")
        prices.append("Failed")
        
    # URL
    try:
        resultsLevel1 = result.find('div', class_='item-desc')
        resultsLevel2 = resultsLevel1.find('a')
        results_URL = resultsLevel2["href"]
        print(results_URL)
        URLs.append(results_URL)
    except:
        print("Failed")
        URLs.append("Failed")
        
    # Source
    try:
        sources.append("Dean's Beans")
    
    except:
        print("Source failed")
        sources.append("Failed")
        
    # Ratings
    try:
        result_rating = result.find('img_id', class_='recordrating')
        print(result_rating)
        ratings.append(result_rating)
    
    except:
        print("Rating failed")
        ratings.append("Failed")
# Out:
# 10 Pack of Kraft Paper Bags (with Tin Tie)
# Price failed
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/kraft-paper-bags-with-tin-tie.html
# None
# Green Bean (Unroasted) Sampler Pack
# Six 8-oz bags of assorted
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/green-bean-unroasted-coffee-sampler.html
# None
# Home Roasting Kit
# $189.99
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/home-roasting-green-bean-sampler-kit.html
# None
# Organic Colombian Green Coffee (Unroasted)
# 1lb - $5.50
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-colombian-green-coffee-unroasted.html
# None
# Organic Ethiopian Green Coffee (Unroasted)
# 1lb - $5.85
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-ethiopian-yirgacheffe-green-coffee-unroasted.html
# None
# Organic Green Espresso - Smooth (Unroasted)
# 1lb - $5.85
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-green-espresso-smooth-unroasted.html
# None
# Organic Green Espresso - Ultra (Unroasted)
# 1lb - $5.85
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-green-espresso-ultra-unroasted.html
# None
# Organic Guatemalan Green Coffee (Unroasted)
# 1lb - $5.85
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-guatemalan-green-coffee-unroasted.html
# None
# Organic Indonesian Green Coffee - Natural Water Decaf (Unroasted)
# 1lb - $6.50
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-indonesian-green-coffee-natural-water-decaf-unroasted.html
# None
# Organic Mexican Green Coffee (Unroasted)
# 1lb - $5.50
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-mexican-green-coffee-unroasted.html
# None
# Organic Nicaraguan Green Coffee (Unroasted)
# 1lb - $5.50
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-nicaraguan-green-coffee-unroasted.html
# None
# Organic Papua New Guinea Green Coffee (Unroasted)
# 1lb - $5.85
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-papua-new-guinea-green-coffee-unroasted.html
# None

# %%
# Pull lists into a data frame
deansBeansData = {'Name': names, 
                   'Price': prices,
                   'Rating': ratings,
                   'URL': URLs,
                   'Source': sources}
deansBeans = pd.DataFrame(data=deansBeansData)
deansBeans.head()
# Out:
#                                          Name                      Price  \
# 0  10 Pack of Kraft Paper Bags (with Tin Tie)                     Failed
# 1         Green Bean (Unroasted) Sampler Pack  Six 8-oz bags of assorted
# 2                           Home Roasting Kit                    $189.99
# 3  Organic Colombian Green Coffee (Unroasted)                1lb - $5.50
# 4  Organic Ethiopian Green Coffee (Unroasted)                1lb - $5.85
#
#   Rating                                                URL        Source
# 0   None  https://deansbeans.com/our-products/roasted-co...  Dean's Beans
# 1   None  https://deansbeans.com/our-products/roasted-co...  Dean's Beans
# 2   None  https://deansbeans.com/our-products/roasted-co...  Dean's Beans
# 3   None  https://deansbeans.com/our-products/roasted-co...  Dean's Beans
# 4   None  https://deansbeans.com/our-products/roasted-co...  Dean's Beans

# %%
test_df = deansBeans
test_df['Price'] = deansBeans['Price'].str.rsplit()
test_df.head()
# Out:
#                                          Name  \
# 0  10 Pack of Kraft Paper Bags (with Tin Tie)
# 1         Green Bean (Unroasted) Sampler Pack
# 2                           Home Roasting Kit
# 3  Organic Colombian Green Coffee (Unroasted)
# 4  Organic Ethiopian Green Coffee (Unroasted)
#
#                              Price Rating  \
# 0                         [Failed]   None
# 1  [Six, 8-oz, bags, of, assorted]   None
# 2                        [$189.99]   None
# 3                  [1lb, -, $5.50]   None
# 4                  [1lb, -, $5.85]   None
#
#                                                  URL        Source
# 0  https://deansbeans.com/our-products/roasted-co...  Dean's Beans
# 1  https://deansbeans.com/our-products/roasted-co...  Dean's Beans
# 2  https://deansbeans.com/our-products/roasted-co...  Dean's Beans
# 3  https://deansbeans.com/our-products/roasted-co...  Dean's Beans
# 4  https://deansbeans.com/our-products/roasted-co...  Dean's Beans

# %%
for i in test_df['Price']:
    print("Row information:")
    print(f"Length: {len(i)}")
    print(f"Row content: {i}")
    finalEntry = len(i)-1
    print(finalEntry)
    print(f"\n")
    print("Final List Element:") 
    print(test_df['Price'][finalEntry])
    print(f"\n")
# Out:
# Row information:
# Length: 1
# Row content: ['Failed']
# 0
#
#
# Final List Element:
# ['Failed']
#
#
# Row information:
# Length: 5
# Row content: ['Six', '8-oz', 'bags', 'of', 'assorted']
# 4
#
#
# Final List Element:
# ['1lb', '-', '$5.85']
#
#
# Row information:
# Length: 1
# Row content: ['$189.99']
# 0
#
#
# Final List Element:
# ['Failed']
#
#
# Row information:
# Length: 3
# Row content: ['1lb', '-', '$5.50']
# 2
#
#
# Final List Element:
# ['$189.99']
#
#
# Row information:
# Length: 3
# Row content: ['1lb', '-', '$5.85']
# 2
#
#
# Final List Element:
# ['$189.99']
#
#
# Row information:
# Length: 3
# Row content: ['1lb', '-', '$5.85']
# 2
#
#
# Final List Element:
# ['$189.99']
#
#
# Row information:
# Length: 3
# Row content: ['1lb', '-', '$5.85']
# 2
#
#
# Final List Element:
# ['$189.99']
#
#
# Row information:
# Length: 3
# Row content: ['1lb', '-', '$5.85']
# 2
#
#
# Final List Element:
# ['$189.99']
#
#
# Row information:
# Length: 3
# Row content: ['1lb', '-', '$6.50']
# 2
#
#
# Final List Element:
# ['$189.99']
#
#
# Row information:
# Length: 3
# Row content: ['1lb', '-', '$5.50']
# 2
#
#
# Final List Element:
# ['$189.99']
#
#
# Row information:
# Length: 3
# Row content: ['1lb', '-', '$5.50']
# 2
#
#
# Final List Element:
# ['$189.99']
#
#
# Row information:
# Length: 3
# Row content: ['1lb', '-', '$5.85']
# 2
#
#
# Final List Element:
# ['$189.99']

# %%
# Remove extra words from Price

# %%
# Remove dollar sign from Price
deansBeans['Price'] = deansBeans['Price'].str.replace('$', '')
deansBeans.head()

# %% [markdown]
# # Scrape Fresh Roasted Coffee for:
# - Name (listing title)
# - Price (listing price)
# - Star Rating (Number of stars given, out of five.)
# - Source (Amazon)
# - URL (link to the bean's individual page)

# %%
# Launch the browser
browser.visit(freshRoastedCoffeeURL)

# %%
# Pull in browser content to form the soup
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Narrow the search scope to the product container
resultFreshLayer1 = soup.find_all('div', class_='bc-sf-filter-product-item-inner')
resultFreshLayer2 = soup.find_all('div', class_='bc-sf-filter-product-bottom')
resultFreshLayer3 = soup.find_all('span', class_='yotpo-stars')
resultFreshLayer4 = soup.find_all('p', class_='bc-sf-filter-product-item-price')

# %%
# URL
URLs = []

for result in resultFreshLayer1:
    try:
        baseURL = 'https://www.freshroastedcoffee.com'
        result_URL = result.find('a')
        completeURL = baseURL + result_URL["href"]
        print(completeURL)
        URLs.append(completeURL)
    except:
        print("URL failed")
        URLs.append("Failed")
# Out:
# https://www.freshroastedcoffee.com/collections/green-coffee/products/colombian-fto-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/guatemala-huehuetenango-fto-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/organic-bali-blue-moon-rfa-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/costa-rica-tarrazu-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/organic-mexican-chiapas-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/sumatra-fto-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/organic-java-taman-dadar-rfa-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/ethiopian-yirgacheffe-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/ethiopian-sidamo-fto-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/colombian-supremo-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/ethiopian-yirgacheffe-fto-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/100-jamaica-blue-mountain-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/kenya-aa-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/sumatra-mandheling-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/honduran-marcala-fto-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/peru-fto-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/organic-haitian-blue-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/brazil-cerrado-green-coffee

# %%
# Name and source
names = []
sources = []

for result in resultFreshLayer2:
    # Name
    try:
        result_name = result.find('p').text
        print(result_name)
        names.append(result_name)
    
    except:
        print("Name failed")
        names.append("Failed")
        
    # Source
    try:
        result_source = result.find('p', class_='bc-sf-filter-product-item-vendor').text
        print(result_source)
        sources.append(result_source)
    
    except:
        print("Source failed")
        sources.append("Failed")
# Out:
# Unroasted Organic Colombian Sierra Nevada Green Coffee - Fair Trade
# Fresh Roasted Coffee
# Unroasted Organic Guatemala Huehuetenango Green Coffee - Fair Trade
# Fresh Roasted Coffee
# Unroasted Organic Bali Blue Moon Green Coffee - RFA
# Fresh Roasted Coffee
# Unroasted Costa Rica Tarrazu Green Coffee
# Fresh Roasted Coffee
# Unroasted Organic Mexican Chiapas Green Coffee
# Fresh Roasted Coffee
# Unroasted Organic Sumatra Green Coffee - Fair Trade, RFA
# Fresh Roasted Coffee
# Unroasted Organic Java Taman Dadar Green Coffee - RFA
# Fresh Roasted Coffee
# Unroasted Ethiopian Yirgacheffe Kochere Green Coffee
# Fresh Roasted Coffee
# Unroasted Organic Ethiopian Sidamo Green Coffee - Fair Trade
# Fresh Roasted Coffee
# Unroasted Colombian Supremo Green Coffee
# Fresh Roasted Coffee
# Unroasted Organic Ethiopian Yirgacheffe Green Coffee - Fair Trade
# Fresh Roasted Coffee
# Unroasted 100% Jamaica Blue Mountain Green Coffee - Direct Trade
# Fresh Roasted Coffee
# Unroasted Kenya AA Green Coffee
# Fresh Roasted Coffee
# Unroasted Sumatra Mandheling Green Coffee
# Fresh Roasted Coffee
# Unroasted Organic Honduran Marcala Green Coffee - Fair Trade
# Fresh Roasted Coffee
# Unroasted Organic Peru Sol y Café Green Coffee - Fair Trade
# Fresh Roasted Coffee
# Unroasted Organic Haitian Blue Green Coffee - Direct Trade
# Fresh Roasted Coffee
# Unroasted Brazil Cerrado Green Coffee
# Fresh Roasted Coffee

# %%
# Prices
prices = []
for result in resultFreshLayer4:
    try: 
        result_price = result.find('span', class_='bc-sf-filter-product-item-regular-price').text
        print(result_price)
        prices.append(result_price)
    
    except:
        print("Price failed")
        prices.append("Failed")
# Out:
# $8.95
# $7.95
# $10.95
# $6.95
# $6.95
# $8.50
# $6.95
# $7.95
# $7.95
# $6.95
# $8.95
# $29.95
# $8.95
# $7.95
# $7.95
# $8.95
# $14.95
# $5.95

# %%
# Ratings
ratings = []
for result in resultFreshLayer3:
    try: 
        result_rating = result.find('span', class_='sr-only').text
        print(result_rating)
        ratings.append(result_rating)
    
    except:
        print("Rating failed")
        ratings.append("Failed")
# Out:
# 5 star rating
# 5.0 star rating
# 4.7 star rating
# 4.7 star rating
# 4.8 star rating
# 5.0 star rating
# 4.6 star rating
# 4.8 star rating
# 4.9 star rating
# 4.8 star rating
# 4.9 star rating
# 4.8 star rating
# 5.0 star rating
# 4.9 star rating
# 5.0 star rating
# 4.7 star rating
# 4.9 star rating
# 4.8 star rating
# 4.7 star rating

# %%
# Remove the last item in the ratings list (due to incorrect info)
ratings.pop()
print(ratings)
# Out:
# ['5 star rating', '5.0 star rating', '4.7 star rating', '4.7 star rating', '4.8 star rating', '5.0 star rating', '4.6 star rating', '4.8 star rating', '4.9 star rating', '4.8 star rating', '4.9 star rating', '4.8 star rating', '5.0 star rating', '4.9 star rating', '5.0 star rating', '4.7 star rating', '4.9 star rating', '4.8 star rating']

# %%
# Pull lists into a data frame
freshRoastData = {'Name': names, 
                   'Price': prices,
                   'Rating': ratings,
                   'URL': URLs,
                   'Source': sources}
freshRoast = pd.DataFrame(data=freshRoastData)
freshRoast.head()
# Out:
#                                                 Name   Price           Rating  \
# 0  Unroasted Organic Colombian Sierra Nevada Gree...   $8.95    5 star rating
# 1  Unroasted Organic Guatemala Huehuetenango Gree...   $7.95  5.0 star rating
# 2  Unroasted Organic Bali Blue Moon Green Coffee ...  $10.95  4.7 star rating
# 3          Unroasted Costa Rica Tarrazu Green Coffee   $6.95  4.7 star rating
# 4     Unroasted Organic Mexican Chiapas Green Coffee   $6.95  4.8 star rating
#
#                                                  URL                Source
# 0  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 1  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 2  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 3  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 4  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee

# %%
# Remove the dollar sign in Price
freshRoast['Price'] = freshRoast['Price'].str.replace('$', '')

# Remove extra words in Rating
freshRoast['Rating'] = freshRoast['Rating'].str.replace('star rating', '')

freshRoast.head()
# Out:
#                                                 Name  Price Rating  \
# 0  Unroasted Organic Colombian Sierra Nevada Gree...   8.95     5
# 1  Unroasted Organic Guatemala Huehuetenango Gree...   7.95   5.0
# 2  Unroasted Organic Bali Blue Moon Green Coffee ...  10.95   4.7
# 3          Unroasted Costa Rica Tarrazu Green Coffee   6.95   4.7
# 4     Unroasted Organic Mexican Chiapas Green Coffee   6.95   4.8
#
#                                                  URL                Source
# 0  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 1  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 2  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 3  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 4  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee

# %% [markdown]
# ### Create database connection

# %%
# Configure the database connection
rds_connection_string = "postgres:88653680Dd!@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirm the existing tables
engine.table_names()

# %% [markdown]
# ### Load DataFrames into database

# %%
# Copy and rename DFs for each DF being loaded
df.to_sql(name='coffee', con=engine, if_exists='replace', index=False)

# %% [markdown]
# # Confirm data has been added

# %%
# Read the table data from SQL
pd.read_sql_query('select * from coffee', con=engine).head()
