# %% [markdown]
# # Setup

# %%
# Import dependencies
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
from splinter import Browser
from bs4 import BeautifulSoup
from flask import Flask, jsonify

# %%
# Configure browser for scraping
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Define URL variables
coffeeBeanCorralURL = 'https://www.coffeebeancorral.com/categories/Green-Coffee-Beans/All-Coffees.aspx'
freshRoastedCoffeeURL = 'https://www.freshroastedcoffee.com/collections/green-coffee'
amazonURL = 'https://www.amazon.com/Best-Sellers-Grocery-Gourmet-Food-Unroasted-Coffee-Beans/zgbs/grocery/979887011'

# %% [markdown]
# Scrape Coffee Bean Corral for:
# - Name (listing title)
# - Price (listing price)
# - Star Rating (Number of stars given, out of five.)
# - Source (Coffee Bean Corral)
# - URL (link to the bean's individual page)

# %%
# Launch the browser
browser.visit(coffeeBeanCorralURL)

# %%
# Pull in browser content to form the soup
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Narrow the search scope to the product container
results = soup.find_all('div', class_='product-info')
print(results)
# Out:
# [<div class="product-info">
# <div class="SingleProductDisplayName recordname">
# <a href="/product/Bali-Hai-Organic-Blend-SWP-Decaf.aspx" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl01_SingleProductDisplay_NameHyperLink">Bali Hai Organic Decaf Indonesia Blend SWP</a>
# </div>
# <div id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl01_SingleProductDisplay_SingleProductDisplayRating">
# <img alt="5 stars" class="recordrating" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl01_SingleProductDisplay_RatingStars" src="/BVModules/Themes/CoffeeBean/images/buttons/Stars5.svg" style="border-width:0px;"/>
# <a class="recordreviewcount" href="/product/Bali-Hai-Organic-Blend-SWP-Decaf.aspx#Write" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl01_SingleProductDisplay_ReviewCount">20 reviews</a>
# </div>
# <div class="SingleProductDisplayPrice recordprice">
# <div class="SingleProductDisplayListPrice recordlistprice" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl01_SingleProductDisplay_listPricePanel">
# <span class="ListPriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl01_SingleProductDisplay_ListPriceLabel">$7.00</span>
# </div>
# <span class="PriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl01_SingleProductDisplay_PriceLabel">$6.30</span>
# </div>
# <div class="recordreveal">
# <div class="SingleProductDisplayDescription recorddesc">
# <span class="DescriptionLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl01_SingleProductDisplay_DescriptionLabel">Muted, earthy, fruit tones and a strong caramelly overtone that permeates the pallette all the way through to the aftertaste.</span>
# </div>
# <div class="SingleProductDisplayQuantity recordqty">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl01_SingleProductDisplay_QuantityRequiredFieldValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl01_SingleProductDisplay_QuantityRequiredFieldValidator" style="display:none;">*</span></span>
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl01_SingleProductDisplay_QuantityRegularExpressionValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl01_SingleProductDisplay_QuantityRegularExpressionValidator" style="display:none;">*</span></span>
# </div>
# <div class="SingleProductDisplayAddToCart recordAddToCart">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl01_SingleProductDisplay_AddToCartImageButton__"></span>
# </div>
# </div>
# <div class="SingleProductDisplayAddedToCart recordadded">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl01_SingleProductDisplay_AddedToCartLabel__"></span>
# </div>
# </div>, <div class="product-info">
# <div class="SingleProductDisplayName recordname">
# <a href="/product/Bali-Organic-Blue-Moon__BALIBEANS.aspx" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl02_SingleProductDisplay_NameHyperLink">Bali Organic Blue Moon</a>
# </div>
# <div id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl02_SingleProductDisplay_SingleProductDisplayRating">
# <img alt="5 stars" class="recordrating" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl02_SingleProductDisplay_RatingStars" src="/BVModules/Themes/CoffeeBean/images/buttons/Stars5.svg" style="border-width:0px;"/>
# <a class="recordreviewcount" href="/product/Bali-Organic-Blue-Moon__BALIBEANS.aspx#Write" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl02_SingleProductDisplay_ReviewCount">30 reviews</a>
# </div>
# <div class="SingleProductDisplayPrice recordprice">
# <span class="PriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl02_SingleProductDisplay_PriceLabel">$7.75</span>
# </div>
# <div class="recordreveal">
# <div class="SingleProductDisplayDescription recorddesc">
# <span class="DescriptionLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl02_SingleProductDisplay_DescriptionLabel">This has an anise flavor which adds spice to the dark chocolate and vanilla bean flavors.</span>
# </div>
# <div class="SingleProductDisplayQuantity recordqty">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl02_SingleProductDisplay_QuantityRequiredFieldValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl02_SingleProductDisplay_QuantityRequiredFieldValidator" style="display:none;">*</span></span>
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl02_SingleProductDisplay_QuantityRegularExpressionValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl02_SingleProductDisplay_QuantityRegularExpressionValidator" style="display:none;">*</span></span>
# </div>
# <div class="SingleProductDisplayAddToCart recordAddToCart">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl02_SingleProductDisplay_AddToCartImageButton__"></span>
# </div>
# </div>
# <div class="SingleProductDisplayAddedToCart recordadded">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl02_SingleProductDisplay_AddedToCartLabel__"></span>
# </div>
# </div>, <div class="product-info">
# <div class="SingleProductDisplayName recordname">
# <a href="/product/Big-Black-Organic-CBC-Blend__BIGBLACKORG.aspx" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl03_SingleProductDisplay_NameHyperLink">Big Black Organic CBC Blend</a>
# </div>
# <div id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl03_SingleProductDisplay_SingleProductDisplayRating">
# <img alt="5 stars" class="recordrating" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl03_SingleProductDisplay_RatingStars" src="/BVModules/Themes/CoffeeBean/images/buttons/Stars5.svg" style="border-width:0px;"/>
# <a class="recordreviewcount" href="/product/Big-Black-Organic-CBC-Blend__BIGBLACKORG.aspx#Write" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl03_SingleProductDisplay_ReviewCount">6 reviews</a>
# </div>
# <div class="SingleProductDisplayPrice recordprice">
# <span class="PriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl03_SingleProductDisplay_PriceLabel">$6.50</span>
# </div>
# <div class="recordreveal">
# <div class="SingleProductDisplayDescription recorddesc">
# <span class="DescriptionLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl03_SingleProductDisplay_DescriptionLabel">This bold organic coffee blend brings out the best of African and Asian coffee beans.</span>
# </div>
# <div class="SingleProductDisplayQuantity recordqty">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl03_SingleProductDisplay_QuantityRequiredFieldValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl03_SingleProductDisplay_QuantityRequiredFieldValidator" style="display:none;">*</span></span>
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl03_SingleProductDisplay_QuantityRegularExpressionValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl03_SingleProductDisplay_QuantityRegularExpressionValidator" style="display:none;">*</span></span>
# </div>
# <div class="SingleProductDisplayAddToCart recordAddToCart">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl03_SingleProductDisplay_AddToCartImageButton__"></span>
# </div>
# </div>
# <div class="SingleProductDisplayAddedToCart recordadded">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl03_SingleProductDisplay_AddedToCartLabel__"></span>
# </div>
# </div>, <div class="product-info">
# <div class="SingleProductDisplayName recordname">
# <a href="/www/Products/Bolivian-Organic---Caranavi-FT__BOLOCOL.aspx" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl04_SingleProductDisplay_NameHyperLink">Bolivian Organic Caranavi FTO</a>
# </div>
# <div id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl04_SingleProductDisplay_SingleProductDisplayRating">
# <img alt="5 stars" class="recordrating" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl04_SingleProductDisplay_RatingStars" src="/BVModules/Themes/CoffeeBean/images/buttons/Stars5.svg" style="border-width:0px;"/>
# <a class="recordreviewcount" href="/www/Products/Bolivian-Organic---Caranavi-FT__BOLOCOL.aspx#Write" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl04_SingleProductDisplay_ReviewCount">7 reviews</a>
# </div>
# <div class="SingleProductDisplayPrice recordprice">
# <span class="PriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl04_SingleProductDisplay_PriceLabel">$7.75</span>
# </div>
# <div class="recordreveal">
# <div class="SingleProductDisplayDescription recorddesc">
# <span class="DescriptionLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl04_SingleProductDisplay_DescriptionLabel">Light body develops sweetened undertones of fruit near orange, lemon with low acidity. Clean, nutty, chocolate, and malt flavor finish.</span>
# </div>
# <div class="SingleProductDisplayQuantity recordqty">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl04_SingleProductDisplay_QuantityRequiredFieldValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl04_SingleProductDisplay_QuantityRequiredFieldValidator" style="display:none;">*</span></span>
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl04_SingleProductDisplay_QuantityRegularExpressionValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl04_SingleProductDisplay_QuantityRegularExpressionValidator" style="display:none;">*</span></span>
# </div>
# <div class="SingleProductDisplayAddToCart recordAddToCart">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl04_SingleProductDisplay_AddToCartImageButton__"></span>
# </div>
# </div>
# <div class="SingleProductDisplayAddedToCart recordadded">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl04_SingleProductDisplay_AddedToCartLabel__"></span>
# </div>
# </div>, <div class="product-info">
# <div class="SingleProductDisplayName recordname">
# <a href="/product/Brazil-Cerrado-Natural-1718__BRACERRADO.aspx" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl05_SingleProductDisplay_NameHyperLink">Brazil Cerrado Natural 17/18</a>
# </div>
# <div id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl05_SingleProductDisplay_SingleProductDisplayRating">
# <img alt="4 stars" class="recordrating" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl05_SingleProductDisplay_RatingStars" src="/BVModules/Themes/CoffeeBean/images/buttons/Stars4.svg" style="border-width:0px;"/>
# <a class="recordreviewcount" href="/product/Brazil-Cerrado-Natural-1718__BRACERRADO.aspx#Write" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl05_SingleProductDisplay_ReviewCount">3 reviews</a>
# </div>
# <div class="SingleProductDisplayPrice recordprice">
# <div class="SingleProductDisplayListPrice recordlistprice" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl05_SingleProductDisplay_listPricePanel">
# <span class="ListPriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl05_SingleProductDisplay_ListPriceLabel">$5.25</span>
# </div>
# <span class="PriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl05_SingleProductDisplay_PriceLabel">$4.00</span>
# </div>
# <div class="recordreveal">
# <div class="SingleProductDisplayDescription recorddesc">
# <span class="DescriptionLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl05_SingleProductDisplay_DescriptionLabel">Sweet and nutty (peanuts) with the signature ashy note of Brazilians, a hint of citrus and a little vanilla surprise on the finish.</span>
# </div>
# <div class="SingleProductDisplayQuantity recordqty">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl05_SingleProductDisplay_QuantityRequiredFieldValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl05_SingleProductDisplay_QuantityRequiredFieldValidator" style="display:none;">*</span></span>
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl05_SingleProductDisplay_QuantityRegularExpressionValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl05_SingleProductDisplay_QuantityRegularExpressionValidator" style="display:none;">*</span></span>
# </div>
# <div class="SingleProductDisplayAddToCart recordAddToCart">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl05_SingleProductDisplay_AddToCartImageButton__"></span>
# </div>
# </div>
# <div class="SingleProductDisplayAddedToCart recordadded">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl05_SingleProductDisplay_AddedToCartLabel__"></span>
# </div>
# </div>, <div class="product-info">
# <div class="SingleProductDisplayName recordname">
# <a href="/product/Daterra-Espresso-Blend.aspx" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl06_SingleProductDisplay_NameHyperLink">Brazil Daterra CHC Reserve Espresso</a>
# </div>
# <div id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl06_SingleProductDisplay_SingleProductDisplayRating">
# <img alt="5 stars" class="recordrating" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl06_SingleProductDisplay_RatingStars" src="/BVModules/Themes/CoffeeBean/images/buttons/Stars5.svg" style="border-width:0px;"/>
# <a class="recordreviewcount" href="/product/Daterra-Espresso-Blend.aspx#Write" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl06_SingleProductDisplay_ReviewCount">4 reviews</a>
# </div>
# <div class="SingleProductDisplayPrice recordprice">
# <span class="PriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl06_SingleProductDisplay_PriceLabel">$7.25</span>
# </div>
# <div class="recordreveal">
# <div class="SingleProductDisplayDescription recorddesc">
# <span class="DescriptionLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl06_SingleProductDisplay_DescriptionLabel">Daterra Espresso Blend "CHC"</span>
# </div>
# <div class="SingleProductDisplayQuantity recordqty">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl06_SingleProductDisplay_QuantityRequiredFieldValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl06_SingleProductDisplay_QuantityRequiredFieldValidator" style="display:none;">*</span></span>
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl06_SingleProductDisplay_QuantityRegularExpressionValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl06_SingleProductDisplay_QuantityRegularExpressionValidator" style="display:none;">*</span></span>
# </div>
# <div class="SingleProductDisplayAddToCart recordAddToCart">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl06_SingleProductDisplay_AddToCartImageButton__"></span>
# </div>
# </div>
# <div class="SingleProductDisplayAddedToCart recordadded">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl06_SingleProductDisplay_AddedToCartLabel__"></span>
# </div>
# </div>, <div class="product-info">
# <div class="SingleProductDisplayName recordname">
# <a href="/product/Brazil-Bourbon-Peaberry-Daterra-Estate-Pearl-Bourbon__DATPEARLBBN.aspx" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl07_SingleProductDisplay_NameHyperLink">Brazil Daterra Pearl Bourbon Peaberry RFA</a>
# </div>
# <div id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl07_SingleProductDisplay_SingleProductDisplayRating">
# <img alt="5 stars" class="recordrating" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl07_SingleProductDisplay_RatingStars" src="/BVModules/Themes/CoffeeBean/images/buttons/Stars5.svg" style="border-width:0px;"/>
# <a class="recordreviewcount" href="/product/Brazil-Bourbon-Peaberry-Daterra-Estate-Pearl-Bourbon__DATPEARLBBN.aspx#Write" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl07_SingleProductDisplay_ReviewCount">11 reviews</a>
# </div>
# <div class="SingleProductDisplayPrice recordprice">
# <span class="PriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl07_SingleProductDisplay_PriceLabel">$8.50</span>
# </div>
# <div class="recordreveal">
# <div class="SingleProductDisplayDescription recorddesc">
# <span class="DescriptionLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl07_SingleProductDisplay_DescriptionLabel">A harmonious coffee with pronounced sweetness in the aftertaste. Try a medium/medium dark roast to bring out distinctive nuttiness with a hint of soft fruit and low acidity.</span>
# </div>
# <div class="SingleProductDisplayQuantity recordqty">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl07_SingleProductDisplay_QuantityRequiredFieldValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl07_SingleProductDisplay_QuantityRequiredFieldValidator" style="display:none;">*</span></span>
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl07_SingleProductDisplay_QuantityRegularExpressionValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl07_SingleProductDisplay_QuantityRegularExpressionValidator" style="display:none;">*</span></span>
# </div>
# <div class="SingleProductDisplayAddToCart recordAddToCart">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl07_SingleProductDisplay_AddToCartImageButton__"></span>
# </div>
# </div>
# <div class="SingleProductDisplayAddedToCart recordadded">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl07_SingleProductDisplay_AddedToCartLabel__"></span>
# </div>
# </div>, <div class="product-info">
# <div class="SingleProductDisplayName recordname">
# <a href="/product/Brazil-Sweet-Blue-Daterra-Estate__DATBLUE.aspx" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl08_SingleProductDisplay_NameHyperLink">Brazil Daterra Sweet Blue RFA</a>
# </div>
# <div id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl08_SingleProductDisplay_SingleProductDisplayRating">
# <img alt="5 stars" class="recordrating" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl08_SingleProductDisplay_RatingStars" src="/BVModules/Themes/CoffeeBean/images/buttons/Stars5.svg" style="border-width:0px;"/>
# <a class="recordreviewcount" href="/product/Brazil-Sweet-Blue-Daterra-Estate__DATBLUE.aspx#Write" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl08_SingleProductDisplay_ReviewCount">11 reviews</a>
# </div>
# <div class="SingleProductDisplayPrice recordprice">
# <span class="PriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl08_SingleProductDisplay_PriceLabel">$8.50</span>
# </div>
# <div class="recordreveal">
# <div class="SingleProductDisplayDescription recorddesc">
# <span class="DescriptionLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl08_SingleProductDisplay_DescriptionLabel">Lighter roast is very syrupy and sweet with a strong almond character. Medium to medium dark roasts bring out spicy and intense dark cocoa notes that taste like an elegant, spicy chocolate bar.</span>
# </div>
# <div class="SingleProductDisplayQuantity recordqty">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl08_SingleProductDisplay_QuantityRequiredFieldValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl08_SingleProductDisplay_QuantityRequiredFieldValidator" style="display:none;">*</span></span>
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl08_SingleProductDisplay_QuantityRegularExpressionValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl08_SingleProductDisplay_QuantityRegularExpressionValidator" style="display:none;">*</span></span>
# </div>
# <div class="SingleProductDisplayAddToCart recordAddToCart">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl08_SingleProductDisplay_AddToCartImageButton__"></span>
# </div>
# </div>
# <div class="SingleProductDisplayAddedToCart recordadded">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl08_SingleProductDisplay_AddedToCartLabel__"></span>
# </div>
# </div>, <div class="product-info">
# <div class="SingleProductDisplayName recordname">
# <a href="/product/Brazil-Daterra-Estate-Sweet-Yellow-RFA__DATYELLOW.aspx" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl09_SingleProductDisplay_NameHyperLink">Brazil Daterra Sweet Yellow RFA</a>
# </div>
# <div id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl09_SingleProductDisplay_SingleProductDisplayRating">
# <img alt="5 stars" class="recordrating" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl09_SingleProductDisplay_RatingStars" src="/BVModules/Themes/CoffeeBean/images/buttons/Stars5.svg" style="border-width:0px;"/>
# <a class="recordreviewcount" href="/product/Brazil-Daterra-Estate-Sweet-Yellow-RFA__DATYELLOW.aspx#Write" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl09_SingleProductDisplay_ReviewCount">5 reviews</a>
# </div>
# <div class="SingleProductDisplayPrice recordprice">
# <span class="PriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl09_SingleProductDisplay_PriceLabel">$8.50</span>
# </div>
# <div class="recordreveal">
# <div class="SingleProductDisplayDescription recorddesc">
# <span class="DescriptionLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl09_SingleProductDisplay_DescriptionLabel">Good underlying acidity and medium body. The coffee offers a refreshing, clean-sweet aftertaste.</span>
# </div>
# <div class="SingleProductDisplayQuantity recordqty">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl09_SingleProductDisplay_QuantityRequiredFieldValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl09_SingleProductDisplay_QuantityRequiredFieldValidator" style="display:none;">*</span></span>
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl09_SingleProductDisplay_QuantityRegularExpressionValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl09_SingleProductDisplay_QuantityRegularExpressionValidator" style="display:none;">*</span></span>
# </div>
# <div class="SingleProductDisplayAddToCart recordAddToCart">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl09_SingleProductDisplay_AddToCartImageButton__"></span>
# </div>
# </div>
# <div class="SingleProductDisplayAddedToCart recordadded">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl09_SingleProductDisplay_AddedToCartLabel__"></span>
# </div>
# </div>, <div class="product-info">
# <div class="SingleProductDisplayName recordname">
# <a href="/product/Brazil-Villa-Daterra-Estate__DATVILLA.aspx" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl10_SingleProductDisplay_NameHyperLink">Brazil Daterra Villa Borghesi RFA</a>
# </div>
# <div id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl10_SingleProductDisplay_SingleProductDisplayRating">
# <img alt="4 stars" class="recordrating" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl10_SingleProductDisplay_RatingStars" src="/BVModules/Themes/CoffeeBean/images/buttons/Stars4.svg" style="border-width:0px;"/>
# <a class="recordreviewcount" href="/product/Brazil-Villa-Daterra-Estate__DATVILLA.aspx#Write" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl10_SingleProductDisplay_ReviewCount">1 review</a>
# </div>
# <div class="SingleProductDisplayPrice recordprice">
# <span class="PriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl10_SingleProductDisplay_PriceLabel">$8.50</span>
# </div>
# <div class="recordreveal">
# <div class="SingleProductDisplayDescription recorddesc">
# <span class="DescriptionLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl10_SingleProductDisplay_DescriptionLabel">Rich sweet fruit flavors dominate the cup leading to a sweet-clean almost winey finish. The perfect coffee for cold brew, drip, and a single origin espresso.</span>
# </div>
# <div class="SingleProductDisplayQuantity recordqty">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl10_SingleProductDisplay_QuantityRequiredFieldValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl10_SingleProductDisplay_QuantityRequiredFieldValidator" style="display:none;">*</span></span>
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl10_SingleProductDisplay_QuantityRegularExpressionValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl10_SingleProductDisplay_QuantityRegularExpressionValidator" style="display:none;">*</span></span>
# </div>
# <div class="SingleProductDisplayAddToCart recordAddToCart">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl10_SingleProductDisplay_AddToCartImageButton__"></span>
# </div>
# </div>
# <div class="SingleProductDisplayAddedToCart recordadded">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl10_SingleProductDisplay_AddedToCartLabel__"></span>
# </div>
# </div>, <div class="product-info">
# <div class="SingleProductDisplayName recordname">
# <a href="/product/Brazil-Decaf-Sul-di-Minas-Royal-Select__BRASULDIMINAS.aspx" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl11_SingleProductDisplay_NameHyperLink">Brazil Decaf Sul di Minas Royal Select</a>
# </div>
# <div class="SingleProductDisplayPrice recordprice">
# <div class="SingleProductDisplayListPrice recordlistprice" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl11_SingleProductDisplay_listPricePanel">
# <span class="ListPriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl11_SingleProductDisplay_ListPriceLabel">$7.00</span>
# </div>
# <span class="PriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl11_SingleProductDisplay_PriceLabel">$6.30</span>
# </div>
# <div class="recordreveal">
# <div class="SingleProductDisplayDescription recorddesc">
# <span class="DescriptionLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl11_SingleProductDisplay_DescriptionLabel">ALMOND, NUTMEG, MILK CHOCOLATE</span>
# </div>
# <div class="SingleProductDisplayQuantity recordqty">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl11_SingleProductDisplay_QuantityRequiredFieldValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl11_SingleProductDisplay_QuantityRequiredFieldValidator" style="display:none;">*</span></span>
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl11_SingleProductDisplay_QuantityRegularExpressionValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl11_SingleProductDisplay_QuantityRegularExpressionValidator" style="display:none;">*</span></span>
# </div>
# <div class="SingleProductDisplayAddToCart recordAddToCart">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl11_SingleProductDisplay_AddToCartImageButton__"></span>
# </div>
# </div>
# <div class="SingleProductDisplayAddedToCart recordadded">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl11_SingleProductDisplay_AddedToCartLabel__"></span>
# </div>
# </div>, <div class="product-info">
# <div class="SingleProductDisplayName recordname">
# <a href="/product/Brazil-Fazenda-Lagoa-Natural-1718__BRALAGOA.aspx" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl12_SingleProductDisplay_NameHyperLink">Brazil Fazenda Da Lagoa Natural 17/18</a>
# </div>
# <div id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl12_SingleProductDisplay_SingleProductDisplayRating">
# <img alt="5 stars" class="recordrating" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl12_SingleProductDisplay_RatingStars" src="/BVModules/Themes/CoffeeBean/images/buttons/Stars5.svg" style="border-width:0px;"/>
# <a class="recordreviewcount" href="/product/Brazil-Fazenda-Lagoa-Natural-1718__BRALAGOA.aspx#Write" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl12_SingleProductDisplay_ReviewCount">2 reviews</a>
# </div>
# <div class="SingleProductDisplayPrice recordprice">
# <div class="SingleProductDisplayListPrice recordlistprice" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl12_SingleProductDisplay_listPricePanel">
# <span class="ListPriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl12_SingleProductDisplay_ListPriceLabel">$5.25</span>
# </div>
# <span class="PriceLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl12_SingleProductDisplay_PriceLabel">$4.00</span>
# </div>
# <div class="recordreveal">
# <div class="SingleProductDisplayDescription recorddesc">
# <span class="DescriptionLabel" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl12_SingleProductDisplay_DescriptionLabel">Brazil Fazenda Lagoa Natural 17/18</span>
# </div>
# <div class="SingleProductDisplayQuantity recordqty">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl12_SingleProductDisplay_QuantityRequiredFieldValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl12_SingleProductDisplay_QuantityRequiredFieldValidator" style="display:none;">*</span></span>
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl12_SingleProductDisplay_QuantityRegularExpressionValidator__"><span class="oops" id="ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl12_SingleProductDisplay_QuantityRegularExpressionValidator" style="display:none;">*</span></span>
# </div>
# <div class="SingleProductDisplayAddToCart recordAddToCart">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl12_SingleProductDisplay_AddToCartImageButton__"></span>
# </div>
# </div>
# <div class="SingleProductDisplayAddedToCart recordadded">
# <span id="Anthem_ctl00_MainContentHolder_ucDevelisysFacetedSearchProductGrid_ucProductGridDisplay_rpProductGrid_ctl12_SingleProductDisplay_AddedToCartLabel__"></span>
# </div>
# </div>]

# %%
# Loop through all of the results to find the correct data
names = []
prices = []
ratings = []
URLs = []
sources = []


for result in results:
    # Name
    try:
        result_name = result.find('a').text
        print(result_name)
        names.append(result_name)
    except:
        print("Name failed")
        names.append("Failed")
        
    # Prices
    try:
        result_price = result.find('span', class_='PriceLabel').text
        print(result_price)
        prices.append(result_price)
        
    except:
        print("Price failed")
        prices.append("Failed")
        
    # Ratings
    try:
        result_rating = result.find('img_id', class_='recordrating')
        print(result_rating)
        ratings.append(result_rating)
    
    except:
        print("Rating failed")
        ratings.append("Failed")
        
    # URL
    try:
        baseURL = 'https://www.coffeebeancorral.com'
        result_URL = result.find('a')
        completeURL = baseURL + result_URL["href"]
        print(completeURL)
        URLs.append(completeURL)
    
    except:
        print("URL failed")
        URLs.append("Failed")
        
    # Source
    try:
        sources.append("Coffee Bean Corral")
    
    except:
        print("Source failed")
        sources.append("Failed")
# Out:
# Bali Hai Organic Decaf Indonesia Blend SWP
# $6.30
# None
# https://www.coffeebeancorral.com/product/Bali-Hai-Organic-Blend-SWP-Decaf.aspx
# Bali Organic Blue Moon
# $7.75
# None
# https://www.coffeebeancorral.com/product/Bali-Organic-Blue-Moon__BALIBEANS.aspx
# Big Black Organic CBC Blend
# $6.50
# None
# https://www.coffeebeancorral.com/product/Big-Black-Organic-CBC-Blend__BIGBLACKORG.aspx
# Bolivian Organic Caranavi FTO
# $7.75
# None
# https://www.coffeebeancorral.com/www/Products/Bolivian-Organic---Caranavi-FT__BOLOCOL.aspx
# Brazil Cerrado Natural 17/18
# $4.00
# None
# https://www.coffeebeancorral.com/product/Brazil-Cerrado-Natural-1718__BRACERRADO.aspx
# Brazil Daterra CHC Reserve Espresso
# $7.25
# None
# https://www.coffeebeancorral.com/product/Daterra-Espresso-Blend.aspx
# Brazil Daterra Pearl Bourbon Peaberry RFA
# $8.50
# None
# https://www.coffeebeancorral.com/product/Brazil-Bourbon-Peaberry-Daterra-Estate-Pearl-Bourbon__DATPEARLBBN.aspx
# Brazil Daterra Sweet Blue RFA
# $8.50
# None
# https://www.coffeebeancorral.com/product/Brazil-Sweet-Blue-Daterra-Estate__DATBLUE.aspx
# Brazil Daterra Sweet Yellow RFA
# $8.50
# None
# https://www.coffeebeancorral.com/product/Brazil-Daterra-Estate-Sweet-Yellow-RFA__DATYELLOW.aspx
# Brazil Daterra Villa Borghesi RFA
# $8.50
# None
# https://www.coffeebeancorral.com/product/Brazil-Villa-Daterra-Estate__DATVILLA.aspx
# Brazil Decaf Sul di Minas Royal Select
# $6.30
# None
# https://www.coffeebeancorral.com/product/Brazil-Decaf-Sul-di-Minas-Royal-Select__BRASULDIMINAS.aspx
# Brazil Fazenda Da Lagoa Natural 17/18
# $4.00
# None
# https://www.coffeebeancorral.com/product/Brazil-Fazenda-Lagoa-Natural-1718__BRALAGOA.aspx

# %%
# Pull lists into a data frame
coffeeCorralData = {'Name': names, 
                   'Price': prices,
                   'Rating': ratings,
                   'URL': URLs,
                   'Source': sources}
coffeeCorral = pd.DataFrame(data=coffeeCorralData)
coffeeCorral.head()
# Out:
#                                          Name  Price Rating  \
# 0  Bali Hai Organic Decaf Indonesia Blend SWP  $6.30   None
# 1                      Bali Organic Blue Moon  $7.75   None
# 2                 Big Black Organic CBC Blend  $6.50   None
# 3               Bolivian Organic Caranavi FTO  $7.75   None
# 4                Brazil Cerrado Natural 17/18  $4.00   None
#
#                                                  URL              Source
# 0  https://www.coffeebeancorral.com/product/Bali-...  Coffee Bean Corral
# 1  https://www.coffeebeancorral.com/product/Bali-...  Coffee Bean Corral
# 2  https://www.coffeebeancorral.com/product/Big-B...  Coffee Bean Corral
# 3  https://www.coffeebeancorral.com/www/Products/...  Coffee Bean Corral
# 4  https://www.coffeebeancorral.com/product/Brazi...  Coffee Bean Corral

# %%
# Remove dollar sign from Price
coffeeCorral['Price'] = coffeeCorral['Price'].str.replace('$', '')
coffeeCorral.head()
# Out:
#                                          Name Price Rating  \
# 0  Bali Hai Organic Decaf Indonesia Blend SWP  6.30   None
# 1                      Bali Organic Blue Moon  7.75   None
# 2                 Big Black Organic CBC Blend  6.50   None
# 3               Bolivian Organic Caranavi FTO  7.75   None
# 4                Brazil Cerrado Natural 17/18  4.00   None
#
#                                                  URL              Source
# 0  https://www.coffeebeancorral.com/product/Bali-...  Coffee Bean Corral
# 1  https://www.coffeebeancorral.com/product/Bali-...  Coffee Bean Corral
# 2  https://www.coffeebeancorral.com/product/Big-B...  Coffee Bean Corral
# 3  https://www.coffeebeancorral.com/www/Products/...  Coffee Bean Corral
# 4  https://www.coffeebeancorral.com/product/Brazi...  Coffee Bean Corral

# %% [markdown]
# Scrape Amazon for:
# - Name (listing title)
# - Price (listing price)
# - Star Rating (Number of stars given, out of five.)
# - Source (Amazon)
# - URL (link to the bean's individual page)
