# %% [markdown]
# # Setup

# %%
# Import dependencies
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
from splinter import Browser
from bs4 import BeautifulSoup
from flask import Flask, jsonify

# %%
# Configure browser for scraping

# Mac path
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}

# Windows path
# executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Define URL variables
coffeeBeanCorralURL = 'https://www.coffeebeancorral.com/categories/Green-Coffee-Beans/All-Coffees.aspx'
freshRoastedCoffeeURL = 'https://www.freshroastedcoffee.com/collections/green-coffee'
amazonURL = 'https://www.amazon.com/Best-Sellers-Grocery-Gourmet-Food-Unroasted-Coffee-Beans/zgbs/grocery/979887011'
deansBeansURL = 'https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans.html'

# %% [markdown]
# # Scrape Coffee Bean Corral for:
# - Name (listing title)
# - Price (listing price)
# - Star Rating (Number of stars given, out of five.)
# - Source (Coffee Bean Corral)
# - URL (link to the bean's individual page)

# %%
# Launch the browser
browser.visit(coffeeBeanCorralURL)

# %%
# Pull in browser content to form the soup
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Narrow the search scope to the product container
results = soup.find_all('div', class_='product-info')
# print(results)

# %%
# Loop through all of the results to find the correct data
names = []
prices = []
ratings = []
URLs = []
sources = []


for result in results:
    # Name
    try:
        result_name = result.find('a').text
        print(result_name)
        names.append(result_name)
    except:
        print("Name failed")
        names.append("Failed")
        
    # Prices
    try:
        result_price = result.find('span', class_='PriceLabel').text
        print(result_price)
        prices.append(result_price)
        
    except:
        print("Price failed")
        prices.append("Failed")
        
    # Ratings
    try:
        result_rating = result.find('img_id', class_='recordrating')
        print(result_rating)
        ratings.append(result_rating)
    
    except:
        print("Rating failed")
        ratings.append("Failed")
        
    # URL
    try:
        baseURL = 'https://www.coffeebeancorral.com'
        result_URL = result.find('a')
        completeURL = baseURL + result_URL["href"]
        print(completeURL)
        URLs.append(completeURL)
    
    except:
        print("URL failed")
        URLs.append("Failed")
        
    # Source
    try:
        sources.append("Coffee Bean Corral")
    
    except:
        print("Source failed")
        sources.append("Failed")
# Out:
# Bali Hai Organic Decaf Indonesia Blend SWP
# $6.30
# None
# https://www.coffeebeancorral.com/product/Bali-Hai-Organic-Blend-SWP-Decaf.aspx
# Bali Organic Blue Moon
# $7.75
# None
# https://www.coffeebeancorral.com/product/Bali-Organic-Blue-Moon__BALIBEANS.aspx
# Big Black Organic CBC Blend
# $6.50
# None
# https://www.coffeebeancorral.com/product/Big-Black-Organic-CBC-Blend__BIGBLACKORG.aspx
# Brazil Cerrado Natural 17/18
# $4.00
# None
# https://www.coffeebeancorral.com/product/Brazil-Cerrado-Natural-1718__BRACERRADO.aspx
# Brazil Daterra CHC Reserve Espresso
# $7.25
# None
# https://www.coffeebeancorral.com/product/Daterra-Espresso-Blend.aspx
# Brazil Daterra Pearl Bourbon Peaberry RFA
# $8.50
# None
# https://www.coffeebeancorral.com/product/Brazil-Bourbon-Peaberry-Daterra-Estate-Pearl-Bourbon__DATPEARLBBN.aspx
# Brazil Daterra Sweet Blue RFA
# $8.50
# None
# https://www.coffeebeancorral.com/product/Brazil-Sweet-Blue-Daterra-Estate__DATBLUE.aspx
# Brazil Daterra Sweet Yellow RFA
# $8.50
# None
# https://www.coffeebeancorral.com/product/Brazil-Daterra-Estate-Sweet-Yellow-RFA__DATYELLOW.aspx
# Brazil Daterra Villa Borghesi RFA
# $8.50
# None
# https://www.coffeebeancorral.com/product/Brazil-Villa-Daterra-Estate__DATVILLA.aspx
# Brazil Decaf Sul di Minas Royal Select
# $6.30
# None
# https://www.coffeebeancorral.com/product/Brazil-Decaf-Sul-di-Minas-Royal-Select__BRASULDIMINAS.aspx
# Brazil Fazenda Da Lagoa Natural 17/18
# $4.00
# None
# https://www.coffeebeancorral.com/product/Brazil-Fazenda-Lagoa-Natural-1718__BRALAGOA.aspx
# Brazil Oberon Natural 17/18
# $5.00
# None
# https://www.coffeebeancorral.com/product/Brazil-Oberon-Natural-1718__BRAOBERON.aspx

# %%
# Pull lists into a data frame
coffeeCorralData = {'Name': names, 
                   'Price': prices,
                   'Rating': ratings,
                   'URL': URLs,
                   'Source': sources}
coffeeCorral = pd.DataFrame(data=coffeeCorralData)
coffeeCorral.head()
# Out:
#                                          Name  Price Rating  \
# 0  Bali Hai Organic Decaf Indonesia Blend SWP  $6.30   None
# 1                      Bali Organic Blue Moon  $7.75   None
# 2                 Big Black Organic CBC Blend  $6.50   None
# 3                Brazil Cerrado Natural 17/18  $4.00   None
# 4         Brazil Daterra CHC Reserve Espresso  $7.25   None
#
#                                                  URL              Source
# 0  https://www.coffeebeancorral.com/product/Bali-...  Coffee Bean Corral
# 1  https://www.coffeebeancorral.com/product/Bali-...  Coffee Bean Corral
# 2  https://www.coffeebeancorral.com/product/Big-B...  Coffee Bean Corral
# 3  https://www.coffeebeancorral.com/product/Brazi...  Coffee Bean Corral
# 4  https://www.coffeebeancorral.com/product/Dater...  Coffee Bean Corral

# %%
# Remove dollar sign from Price
coffeeCorral['Price'] = coffeeCorral['Price'].str.replace('$', '')
coffeeCorral.head()
# Out:
#                                          Name Price Rating  \
# 0  Bali Hai Organic Decaf Indonesia Blend SWP  6.30   None
# 1                      Bali Organic Blue Moon  7.75   None
# 2                 Big Black Organic CBC Blend  6.50   None
# 3                Brazil Cerrado Natural 17/18  4.00   None
# 4         Brazil Daterra CHC Reserve Espresso  7.25   None
#
#                                                  URL              Source
# 0  https://www.coffeebeancorral.com/product/Bali-...  Coffee Bean Corral
# 1  https://www.coffeebeancorral.com/product/Bali-...  Coffee Bean Corral
# 2  https://www.coffeebeancorral.com/product/Big-B...  Coffee Bean Corral
# 3  https://www.coffeebeancorral.com/product/Brazi...  Coffee Bean Corral
# 4  https://www.coffeebeancorral.com/product/Dater...  Coffee Bean Corral

# %% [markdown]
# # Scrape Amazon for:
# - Name (listing title)
# - Price (listing price)
# - Star Rating (Number of stars given, out of five.)
# - Source (Amazon)
# - URL (link to the bean's individual page)

# %%
# Launch the browser
browser.visit(amazonURL)

# %%
# Pull in browser content to form the soup
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Narrow the search scope to the product container
results = soup.find_all('span', class_='aok-inline-block zg-item')
# print(results)

# %%
# Loop through all of the results to find the correct data
names = []
prices = []
ratings = []
URLs = []
sources = []


for result in results:
    # Name
    try:
        resultsLevel1 = result.find('a', class_='a-link-normal')
        resultsLevel2 = resultsLevel1.find('span', class_='zg-text-center-align')
        resultsLevel3 = resultsLevel2.find('div', class_='a-section a-spacing-small')
        resultsLevel4 = resultsLevel3.find('img')
        results_name = resultsLevel4["alt"]
        print(results_name)
        names.append(results_name)
    except:
        print("Name failed")
        names.append("Failed")
        
    # URL
    baseURL = 'https://amazon.com'
    try:
        resultsLink = result.find('a', class_='a-link-normal')
        resultsLink = resultsLevel1['href']
        resultsLink = baseURL + resultsLink
        print(resultsLink)
        URLs.append(resultsLink)
    except:
        print("Failed")
        URLs.append("Failed")
        
    # Source
    try:
        sources.append("Amazon Grocery")
    
    except:
        print("Source failed")
        sources.append("Failed")
        
    # Ratings
    try:
        result_rating = result.find('img_id', class_='recordrating')
        print(result_rating)
        ratings.append(result_rating)
    
    except:
        print("Rating failed")
        ratings.append("Failed")
        
    # Price
    try:
        priceResults = soup.find_all('span', class_='p13n-sc-price')

        for result in priceResults:
            print(result.text)
            prices.append(result.text)  
    except:
        print("Price failed")
        prices.append("Failed")
# Out:
# 3 Lbs, Single Origin Unroasted Green Coffee Beans, Specialty Grade From Single Nicaraguan Estate, Direct Trade
# https://amazon.com/Single-Unroasted-Coffee-Specialty-Nicaraguan/dp/B014THN4OI/ref=zg_bs_979887011_1/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Unroasted Green Coffee Bean Sampler Pack - 4LBS - 100% raw arabica coffee beans - COLOMBIA, ETHIOPIA, GUATEMALA, COSTA RICA, BRAZIL
# https://amazon.com/Unroasted-Green-Coffee-Bean-Sampler/dp/B07RMKVJ24/ref=zg_bs_979887011_2/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# COLOMBIAN SUPREMO Unroasted Green Raw Coffee Beans, 5 LB Bulk Bag, 100% Arabica Top Grade Extra Large
# https://amazon.com/COLOMBIAN-SUPREMO-Unroasted-Coffee-Arabica/dp/B0792L8BDV/ref=zg_bs_979887011_3/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# 3 Lb, Single Origin Unroasted Green Coffee Beans, Specialty Grade From Single Nicaraguan Estate, Direct Trade (Variety Pack)
# https://amazon.com/Unroasted-Coffee-Specialty-Nicaraguan-Variety/dp/B01MSS6DCD/ref=zg_bs_979887011_4/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Costa Rica Dota Estate, Green Unroasted Coffee Beans, 3 lb
# https://amazon.com/Costa-Estate-Green-Unroasted-Coffee/dp/B00EN75754/ref=zg_bs_979887011_5/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Anthony's Organic Unroasted Whole Green Coffee Beans, 2lbs, Mexican Altura Arabica Beans, Raw, Batch Tested and Gluten Free
# https://amazon.com/Anthonys-Organic-Unroasted-Mexican-Arabica/dp/B07N4C4PSB/ref=zg_bs_979887011_6/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Green Unroasted Coffee Beans, 5 LB. Bag, Fresh Roasted Coffee LLC. (Colombian Supremo)
# https://amazon.com/Roasted-LLC-Unroasted-Colombian-Supremo/dp/B00E7UMXN6/ref=zg_bs_979887011_7/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Ethiopian Yirgacheffe Green Unroasted Coffee Beans 1 Pound
# https://amazon.com/Ethiopian-Yirgacheffe-Green-Unroasted-Coffee/dp/B0129X141Y/ref=zg_bs_979887011_8/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Costa Rica Dota Estate, Green Unroasted Coffee Beans, 1lb
# https://amazon.com/Costa-Estate-Green-Unroasted-Coffee/dp/B00EN74TBM/ref=zg_bs_979887011_9/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Green Unroasted Coffee Beans, 5 LB. Bag, Fresh Roasted Coffee LLC. (Brazilian Cerrado)
# https://amazon.com/Roasted-LLC-Unroasted-Brazilian-Cerrado/dp/B00DJA51D4/ref=zg_bs_979887011_10/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Brazil Adrano Volcano Coffee, Green Unroasted Coffee Beans (10 LB)
# https://amazon.com/Brazil-Adrano-Volcano-Coffee-Unroasted/dp/B00UCGABQ0/ref=zg_bs_979887011_11/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Fresh Roasted Coffee LLC, Green Unroasted Colombian Sierra Nevada Coffee Beans, Fair Trade, USDA Organic, 5 Pound Bag
# https://amazon.com/Roasted-LLC-Unroasted-Colombian-Organic/dp/B01AYARO2C/ref=zg_bs_979887011_12/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Fresh Roasted Coffee LLC, Green Unroasted Sumatra Coffee Beans, Fair Trade, USDA Organic, 5 Pound Bag
# https://amazon.com/Roasted-LLC-Unroasted-Sumatra-Organic/dp/B01AYARLBG/ref=zg_bs_979887011_13/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Taylors of Harrogate Assam, 20 Count(Pack of 1)
# https://amazon.com/Taylors-Harrogate-Assam-20-Teabags/dp/B01DO013YO/ref=zg_bs_979887011_14/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# 3LB Single Estate Nicaragua Unroasted Green Coffee Beans, Premium Specialty Grade 100% Arabica Coffee for Home Roasters from CoCoffee
# https://amazon.com/Nicaragua-Unroasted-Specialty-Roasters-CoCoffee/dp/B079SDL5ZF/ref=zg_bs_979887011_15/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Fresh Roasted Coffee LLC, Green Unroasted Ethiopian Yirgacheffe Kochere Coffee Beans, 5 Pound Bag
# https://amazon.com/Roasted-LLC-Unroasted-Ethiopian-Yirgacheffe/dp/B00HENZCT0/ref=zg_bs_979887011_16/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Fresh Roasted Coffee LLC, Green Unroasted Colombian Decaffeinated Coffee Beans, Swiss Water Process, 5 Pound Bag
# https://amazon.com/Roasted-LLC-Unroasted-Colombian-Decaffeinated/dp/B01GGMF6A4/ref=zg_bs_979887011_17/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Unroasted Coffee Single Origin Specialty Grade Premium Arabica Catucai Red 2lb
# https://amazon.com/Green-Unroasted-Coffee-Brazil-Catucai/dp/B07116HQVK/ref=zg_bs_979887011_18/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# City Centre Coffee Muay Thai Green Whole Bean Coffee from Thailand, 5 lb
# https://amazon.com/City-Centre-Coffee-Green-Whole/dp/B07GYRN3JF/ref=zg_bs_979887011_19/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Fresh Roasted Coffee LLC, Green Unroasted Ethiopian Yirgacheffe Coffee Beans, Fair Trade, USDA Organic, 5 Pound Bag
# https://amazon.com/Roasted-LLC-Unroasted-Ethiopian-Yirgacheffe/dp/B01AYARN3C/ref=zg_bs_979887011_20/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Fine International Coffees, up to 50 Pounds, Unroasted, Green Beans (Guatemala SHG Huehuetenango Huixoc Coffee Bns RFA, 5 pounds)
# https://amazon.com/International-Coffees-Unroasted-Guatemala-Huehuetenango/dp/B00L0GTRB6/ref=zg_bs_979887011_21/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Teasia Coffee, Guatemala Antigua, Single Origin, Green Unroasted Whole Coffee Beans, 5-Pound Bag
# https://amazon.com/Teasia-Guatemala-Antigua-Unroasted-5-Pound/dp/B077Z6F66T/ref=zg_bs_979887011_22/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Fresh Roasted Coffee LLC, Green Unroasted Papua New Guinea Coffee Beans, 5 Pound Bag
# https://amazon.com/Fresh-Roasted-Coffee-Unroasted-Guinea/dp/B00JEGSBQG/ref=zg_bs_979887011_23/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Green Unroasted Coffee, 5 Lb. Bag, Fresh Roasted Coffee LLC. (Guatemala Huehuetenango)
# https://amazon.com/Roasted-LLC-Unroasted-Guatemalan-Huehuetenango/dp/B01GGMF5LY/ref=zg_bs_979887011_24/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Green Coffee Direct Trade Micro Lot Sustainable Volcanic Soil Single Estate Farm Blend 2lb
# https://amazon.com/Green-Unroasted-Coffee-Brazil-Blend/dp/B0718YHM6T/ref=zg_bs_979887011_25/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Teasia Coffee, Peru Decaf, Single Origin Fair Trade, Green Unroasted Whole Coffee Beans, Specialty Grade, 5-Pound Bag
# https://amazon.com/Teasia-Coffee-Single-Unroasted-5-Pound/dp/B078D6YHXN/ref=zg_bs_979887011_26/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Peaberry Coffee Unroasted Green Single Origin Specialty Grade Premium Arabica Mini Me 2lb
# https://amazon.com/Peaberry-Coffee-Unroasted-Specialty-Premium/dp/B07XCSMF5C/ref=zg_bs_979887011_27/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Single Origin Unroasted Green Coffee Beans, AA Grade From Small Regional Kenyan Coffee Farmer Co-Op. Direct Trade (3 pounds)
# https://amazon.com/Single-Unroasted-Coffee-Regional-Kenyan/dp/B0792JZQKQ/ref=zg_bs_979887011_28/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# COLOMBIAN SUPREMO Unroasted Green Raw Coffee Beans, 2 LB Bag, 100% Arabica Top Grade Extra Large
# https://amazon.com/COLOMBIAN-SUPREMO-Unroasted-Coffee-Arabica/dp/B0792K4XFT/ref=zg_bs_979887011_29/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Teasia Coffee, Ethiopia Sidamo, Single Origin, Green Unroasted Whole Coffee Beans, 5-Pound Bag
# https://amazon.com/Teasia-Coffee-Ethiopia-Unroasted-5-Pound/dp/B077ZF6DMZ/ref=zg_bs_979887011_30/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# COLOMBIAN SUPREMO Unroasted Green Raw Coffee Beans, 1 LB Bag, 100% Arabica Top Grade Extra Large
# https://amazon.com/COLOMBIAN-SUPREMO-Unroasted-Coffee-Arabica/dp/B0792HRC3R/ref=zg_bs_979887011_31/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Green Coffee From Brazil Fair Trade High Elevation Sundried Natural Catucai Yellow 2lb
# https://amazon.com/Unroasted-Coffee-Brazil-Catucai-Yellow/dp/B071KW33FT/ref=zg_bs_979887011_32/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# The Bean Coffee Company Organic Unroasted Green Coffee Beans, Costa Rican, 16-Ounce Bags (Pack of 2)
# https://amazon.com/Bean-Coffee-Company-Unroasted-16-Ounce/dp/B074H7K3NY/ref=zg_bs_979887011_33/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Fresh Roasted Coffee LLC, Green Unroasted Bali Blue Moon Coffee Beans, USDA Organic, RFA, 5 Pound Bag
# https://amazon.com/Roasted-Coffee-LLC-Unroasted-Organic/dp/B00HJ7753C/ref=zg_bs_979887011_34/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Brazil Adrano Volcano Coffee, Green Unroasted Coffee Beans (3 LB)
# https://amazon.com/Brazil-Adrano-Volcano-Coffee-Unroasted/dp/B00KRXR4CM/ref=zg_bs_979887011_35/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Single Origin Unroasted Green Coffee Beans, AA Grade From Small Single Kenyan Farm -Direct Trade (5 pounds)
# https://amazon.com/Single-Unroasted-Coffee-Kenyan-Direct/dp/B0792JRPC8/ref=zg_bs_979887011_36/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Brazil Adrano Volcano Coffee, Green Unroasted Coffee Beans (1 LB)
# https://amazon.com/Heirloom-Coffee-LLC-Volcano-Unroasted/dp/B00KRXR4IG/ref=zg_bs_979887011_37/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# 5 Pounds Brazil Mogiana Green Unroasted Coffee Beans
# https://amazon.com/Pounds-Brazil-Mogiana-Unroasted-Coffee/dp/B01CPGEZVQ/ref=zg_bs_979887011_38/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# 3LBS - Unroasted Green Coffee Beans - Single Origin - Ethiopia Yirgacheffe -100% Raw Green Arabica Coffee Beans - ( Yirgacheffe Region, Ethiopia, Africa)
# https://amazon.com/3LBS-Unroasted-Ethiopia-Yirgacheffe-Arabica/dp/B07T3C32D3/ref=zg_bs_979887011_39/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Fresh Roasted Coffee LLC, Green Unroasted Ethiopian Sidamo Decaffeinated Coffee Beans, Fair Trade, Water Process, USDA Organic, 5 Pound Bag
# https://amazon.com/Roasted-LLC-Unroasted-Ethiopian-Decaffeinated/dp/B01GGMF9T2/ref=zg_bs_979887011_40/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Fresh Roasted Coffee LLC, Green Unroasted Costa Rica Tarrazu Coffee Beans, 5 Pound Bag
# https://amazon.com/Roasted-Coffee-LLC-Unroasted-Tarrazu/dp/B00JEGSBSE/ref=zg_bs_979887011_41/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# 5 Pounds – Central American - Guatemala – Unroasted Arabica Green Coffee Beans – Grown in San Marcos Region – Altitude 1800M – Drying/Milling Process Washed – Finca Nueva Granada - Includes Burlap Bag
# https://amazon.com/Pounds-American-Guatemala-Unroasted-Altitude/dp/B07TBBFPCF/ref=zg_bs_979887011_42/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# ORGANIC Mexico Bellavista (5 LB) Unroasted Raw Green Coffee Beans - Specialty Grade, Single Origin
# https://amazon.com/ORGANIC-Mexico-Jaltenango-Unroasted-Coffee/dp/B075SM7VGX/ref=zg_bs_979887011_43/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# 3Lbs, Single Origin Unroasted Green Coffee Beans, Guatemala Huehuetenango
# https://amazon.com/Single-Unroasted-Coffee-Guatemala-Huehuetenango/dp/B07NDRM7CW/ref=zg_bs_979887011_44/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Green Coffee Powder organic, 100% pure and natural (finely ground, 500g)
# https://amazon.com/Coffee-Powder-organic-natural-finely/dp/B074WF8C1H/ref=zg_bs_979887011_45/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Himalayan Arabica Organic Unroasted Whole Coffee Green Beans - Cupping Score 90 (Value Pack) 100% Hand Picked Sun & Net Dried - World's Best Natural Coffee Grow on High Altitude Of Himalayas, Nepal
# https://amazon.com/Himalayan-Arabica-Green-Beans-Coffee/dp/B07CRN23JY/ref=zg_bs_979887011_46/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Fresh Roasted Coffee LLC, Green Unroasted Tanzanian Peaberry Coffee Beans, 5 Pound Bag
# https://amazon.com/Roasted-LLC-Unroasted-Tanzanian-Peaberry/dp/B00JEGVSZM/ref=zg_bs_979887011_47/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Green Unroasted Coffee Beans, 5 LB. Bag, Fresh Roasted Coffee LLC. (Monsooned Malabar)
# https://amazon.com/Roasted-LLC-Unroasted-Monsooned-Malabar/dp/B00JEGSBQ6/ref=zg_bs_979887011_48/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Teasia Coffee, Brazil Fazenda, Single Origin, Unroasted Whole Green Coffee Beans, 5-Pound Bag
# https://amazon.com/Teasia-Coffee-Fazenda-Unroasted-5-Pound/dp/B077Z6F6WV/ref=zg_bs_979887011_49/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75
# Diesel Coffee Company, "Brazil Cerrado" Green Raw Unroasted Whole Coffee Beans, 3-Pound Bag
# https://amazon.com/Diesel-Coffee-Company-Cerrado-Unroasted/dp/B07FFVLCZN/ref=zg_bs_979887011_50/137-1218378-2326765?_encoding=UTF8&psc=1&refRID=RW1T8QGXR2461BKA6Q2P
# None
# $19.99
# $34.99
# $29.79
# $21.49
# $23.95
# $14.99
# $30.95
# $12.97
# $9.95
# $27.99
# $40.95
# $40.95
# $5.45
# $19.79
# $35.95
# $35.95
# $17.99
# $39.95
# $32.25
# $36.99
# $35.95
# $35.95
# $17.49
# $36.99
# $15.99
# $24.95
# $14.79
# $39.99
# $12.49
# $16.99
# $18.35
# $49.95
# $24.95
# $36.95
# $10.95
# $29.95
# $24.99
# $40.95
# $35.95
# $23.35
# $30.24
# $21.99
# $27.90
# $19.49
# $35.95
# $36.99
# $29.99
# $19.75

# %%
# Pull lists into a data frame
amazonData = {'Name': names, 
                   'Price': prices,
                   'Rating': ratings,
                   'URL': URLs,
                   'Source': sources}
amazon = pd.DataFrame(data=amazonData)
amazon.head()

# %%
# Remove dollar sign from Price
amazon['Price'] = amazon['Price'].str.replace('$', '')
amazon.head()
# Out:
#                                                 Name  Price Rating  \
# 0  3 Lbs, Single Origin Unroasted Green Coffee Be...  19.99   None
# 1  COLOMBIAN SUPREMO Unroasted Green Raw Coffee B...  29.79   None
# 2  Unroasted Green Coffee Bean Sampler Pack - 4LB...  34.99   None
# 3  Ethiopian Yirgacheffe Green Unroasted Coffee B...  12.97   None
# 4  Costa Rica Dota Estate, Green Unroasted Coffee...   9.95   None
#
#                                                  URL          Source
# 0  https://amazon.com/Single-Unroasted-Coffee-Spe...  Amazon Grocery
# 1  https://amazon.com/COLOMBIAN-SUPREMO-Unroasted...  Amazon Grocery
# 2  https://amazon.com/Unroasted-Green-Coffee-Bean...  Amazon Grocery
# 3  https://amazon.com/Ethiopian-Yirgacheffe-Green...  Amazon Grocery
# 4  https://amazon.com/Costa-Estate-Green-Unroaste...  Amazon Grocery

# %% [markdown]
# # Scrape Dean's Beans for:
# - Name (listing title)
# - Price (listing price)
# - Star Rating (Number of stars given, out of five.)
# - Source (Amazon)
# - URL (link to the bean's individual page)

# %%
# Launch the browser
browser.visit(deansBeansURL)

# %%
# Pull in browser content to form the soup
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Narrow the search scope to the product container
results = soup.find_all('div', class_='item-content')
# print(results)

# %%
for result in results:
    try:
        resultsLevel1 = result.find('div', class_='item-desc')
        resultsLevel2 = resultsLevel1.find('a')
        resultsLevel3 = resultsLevel2.find('h5')
        results_price = resultsLevel3.text
        print(results_price)
        prices.append(results_price)
    except:
        print("Failed")
# Out:
# Failed
# Six 8-oz bags of assorted
# $189.99
# 1lb - $5.50
# 1lb - $5.85
# 1lb - $5.85
# 1lb - $5.85
# 1lb - $5.85
# 1lb - $6.50
# 1lb - $5.50
# 1lb - $5.50
# 1lb - $5.85

# %%
# Loop through all of the results to find the correct data
names = []
prices = []
ratings = []
URLs = []
sources = []


for result in results:
    # Name
    try:
        resultsLevel1 = result.find('h2', class_='item-name')
        resultsLevel2 = resultsLevel1.find('a')
        results_name = resultsLevel2["title"]
        print(results_name)
        names.append(results_name)
    except:
        print("Name failed")
        names.append("Failed")
        
    # Price
    try:
        resultsLevel1 = result.find('div', class_='item-desc')
        resultsLevel2 = resultsLevel1.find('a')
        resultsLevel3 = resultsLevel2.find('h5')
        results_price = resultsLevel3.text
        print(results_price)
        prices.append(results_price)
    except:
        print("Price failed")
        prices.append("Failed")
        
    # URL
    try:
        resultsLevel1 = result.find('div', class_='item-desc')
        resultsLevel2 = resultsLevel1.find('a')
        results_URL = resultsLevel2["href"]
        print(results_URL)
        URLs.append(results_URL)
    except:
        print("Failed")
        URLs.append("Failed")
        
    # Source
    try:
        sources.append("Dean's Beans")
    
    except:
        print("Source failed")
        sources.append("Failed")
        
    # Ratings
    try:
        result_rating = result.find('img_id', class_='recordrating')
        print(result_rating)
        ratings.append(result_rating)
    
    except:
        print("Rating failed")
        ratings.append("Failed")
# Out:
# 10 Pack of Kraft Paper Bags (with Tin Tie)
# Price failed
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/kraft-paper-bags-with-tin-tie.html
# None
# Green Bean (Unroasted) Sampler Pack
# Six 8-oz bags of assorted
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/green-bean-unroasted-coffee-sampler.html
# None
# Home Roasting Kit
# $189.99
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/home-roasting-green-bean-sampler-kit.html
# None
# Organic Colombian Green Coffee (Unroasted)
# 1lb - $5.50
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-colombian-green-coffee-unroasted.html
# None
# Organic Ethiopian Green Coffee (Unroasted)
# 1lb - $5.85
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-ethiopian-yirgacheffe-green-coffee-unroasted.html
# None
# Organic Green Espresso - Smooth (Unroasted)
# 1lb - $5.85
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-green-espresso-smooth-unroasted.html
# None
# Organic Green Espresso - Ultra (Unroasted)
# 1lb - $5.85
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-green-espresso-ultra-unroasted.html
# None
# Organic Guatemalan Green Coffee (Unroasted)
# 1lb - $5.85
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-guatemalan-green-coffee-unroasted.html
# None
# Organic Indonesian Green Coffee - Natural Water Decaf (Unroasted)
# 1lb - $6.50
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-indonesian-green-coffee-natural-water-decaf-unroasted.html
# None
# Organic Mexican Green Coffee (Unroasted)
# 1lb - $5.50
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-mexican-green-coffee-unroasted.html
# None
# Organic Nicaraguan Green Coffee (Unroasted)
# 1lb - $5.50
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-nicaraguan-green-coffee-unroasted.html
# None
# Organic Papua New Guinea Green Coffee (Unroasted)
# 1lb - $5.85
# https://deansbeans.com/our-products/roasted-coffees/green-unroasted-coffee-beans/organic-papua-new-guinea-green-coffee-unroasted.html
# None

# %%
# Pull lists into a data frame
deansBeansData = {'Name': names, 
                   'Price': prices,
                   'Rating': ratings,
                   'URL': URLs,
                   'Source': sources}
deansBeans = pd.DataFrame(data=deansBeansData)
deansBeans.head()
# Out:
#                                          Name                      Price  \
# 0  10 Pack of Kraft Paper Bags (with Tin Tie)                     Failed
# 1         Green Bean (Unroasted) Sampler Pack  Six 8-oz bags of assorted
# 2                           Home Roasting Kit                    $189.99
# 3  Organic Colombian Green Coffee (Unroasted)                1lb - $5.50
# 4  Organic Ethiopian Green Coffee (Unroasted)                1lb - $5.85
#
#   Rating                                                URL        Source
# 0   None  https://deansbeans.com/our-products/roasted-co...  Dean's Beans
# 1   None  https://deansbeans.com/our-products/roasted-co...  Dean's Beans
# 2   None  https://deansbeans.com/our-products/roasted-co...  Dean's Beans
# 3   None  https://deansbeans.com/our-products/roasted-co...  Dean's Beans
# 4   None  https://deansbeans.com/our-products/roasted-co...  Dean's Beans

# %%
# Remove extra words from Price

# %%
# Remove dollar sign from Price
deansBeans['Price'] = deansBeans['Price'].str.replace('$', '')
deansBeans.head()

# %% [markdown]
# # Scrape Fresh Roast Coffee for:
# - Name (listing title)
# - Price (listing price)
# - Star Rating (Number of stars given, out of five.)
# - Source (Amazon)
# - URL (link to the bean's individual page)

# %%
# Launch the browser
browser.visit(freshRoastedCoffeeURL)

# %%
# Pull in browser content to form the soup
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Narrow the search scope to the product container
resultFreshLayer1 = soup.find_all('div', class_='bc-sf-filter-product-item-inner')
resultFreshLayer2 = soup.find_all('div', class_='bc-sf-filter-product-bottom')
resultFreshLayer3 = soup.find_all('span', class_='yotpo-stars')
resultFreshLayer4 = soup.find_all('p', class_='bc-sf-filter-product-item-price')

# %%
URLs = []

for result in resultFreshLayer1:
    try:
        baseURL = 'https://www.freshroastedcoffee.com'
        result_URL = result.find('a')
        completeURL = baseURL + result_URL["href"]
        print(completeURL)
        URLs.append(completeURL)
    except:
        print("URL failed")
        URLs.append("Failed")
# Out:
# https://www.freshroastedcoffee.com/collections/green-coffee/products/colombian-fto-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/guatemala-huehuetenango-fto-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/organic-bali-blue-moon-rfa-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/costa-rica-tarrazu-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/organic-mexican-chiapas-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/sumatra-fto-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/organic-java-taman-dadar-rfa-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/ethiopian-yirgacheffe-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/ethiopian-sidamo-fto-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/colombian-supremo-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/ethiopian-yirgacheffe-fto-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/100-jamaica-blue-mountain-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/kenya-aa-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/sumatra-mandheling-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/honduran-marcala-fto-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/peru-fto-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/organic-haitian-blue-green-coffee
# https://www.freshroastedcoffee.com/collections/green-coffee/products/brazil-cerrado-green-coffee

# %%
names = []
sources = []

for result in resultFreshLayer2:
    # Name
    try:
        result_name = result.find('p').text
        print(result_name)
        names.append(result_name)
    
    except:
        print("Name failed")
        names.append("Failed")
        
    # Source
    try:
        result_source = result.find('p', class_='bc-sf-filter-product-item-vendor').text
        print(result_source)
        sources.append(result_source)
    
    except:
        print("Source failed")
        sources.append("Failed")
# Out:
# Unroasted Organic Colombian Sierra Nevada Green Coffee - Fair Trade
# Fresh Roasted Coffee
# Unroasted Organic Guatemala Huehuetenango Green Coffee - Fair Trade
# Fresh Roasted Coffee
# Unroasted Organic Bali Blue Moon Green Coffee - RFA
# Fresh Roasted Coffee
# Unroasted Costa Rica Tarrazu Green Coffee
# Fresh Roasted Coffee
# Unroasted Organic Mexican Chiapas Green Coffee
# Fresh Roasted Coffee
# Unroasted Organic Sumatra Green Coffee - Fair Trade, RFA
# Fresh Roasted Coffee
# Unroasted Organic Java Taman Dadar Green Coffee - RFA
# Fresh Roasted Coffee
# Unroasted Ethiopian Yirgacheffe Kochere Green Coffee
# Fresh Roasted Coffee
# Unroasted Organic Ethiopian Sidamo Green Coffee - Fair Trade
# Fresh Roasted Coffee
# Unroasted Colombian Supremo Green Coffee
# Fresh Roasted Coffee
# Unroasted Organic Ethiopian Yirgacheffe Green Coffee - Fair Trade
# Fresh Roasted Coffee
# Unroasted 100% Jamaica Blue Mountain Green Coffee - Direct Trade
# Fresh Roasted Coffee
# Unroasted Kenya AA Green Coffee
# Fresh Roasted Coffee
# Unroasted Sumatra Mandheling Green Coffee
# Fresh Roasted Coffee
# Unroasted Organic Honduran Marcala Green Coffee - Fair Trade
# Fresh Roasted Coffee
# Unroasted Organic Peru Sol y Café Green Coffee - Fair Trade
# Fresh Roasted Coffee
# Unroasted Organic Haitian Blue Green Coffee - Direct Trade
# Fresh Roasted Coffee
# Unroasted Brazil Cerrado Green Coffee
# Fresh Roasted Coffee

# %%
prices = []
for result in resultFreshLayer4:
    try: 
        result_price = result.find('span', class_='bc-sf-filter-product-item-regular-price').text
        print(result_price)
        prices.append(result_price)
    
    except:
        print("Price failed")
        prices.append("Failed")
# Out:
# $8.95
# $7.95
# $10.95
# $6.95
# $6.95
# $8.50
# $6.95
# $7.95
# $7.95
# $6.95
# $8.95
# $29.95
# $8.95
# $7.95
# $7.95
# $8.95
# $14.95
# $5.95

# %%
ratings = []
for result in resultFreshLayer3:
    try: 
        result_rating = result.find('span', class_='sr-only').text
        print(result_rating)
        ratings.append(result_rating)
    
    except:
        print("Rating failed")
        ratings.append("Failed")
# Out:
# 5 star rating
# 5.0 star rating
# 4.7 star rating
# 4.7 star rating
# 4.8 star rating
# 5.0 star rating
# 4.6 star rating
# 4.8 star rating
# 4.9 star rating
# 4.8 star rating
# 4.9 star rating
# 4.8 star rating
# 5.0 star rating
# 4.9 star rating
# 5.0 star rating
# 4.7 star rating
# 4.9 star rating
# 4.8 star rating
# 4.7 star rating

# %%
# Remove the last item in the ratings list (due to incorrect info)
ratings.pop()
print(ratings)
# Out:
# ['5 star rating', '5.0 star rating', '4.7 star rating', '4.7 star rating', '4.8 star rating', '5.0 star rating', '4.6 star rating', '4.8 star rating', '4.9 star rating', '4.8 star rating', '4.9 star rating', '4.8 star rating', '5.0 star rating', '4.9 star rating', '5.0 star rating', '4.7 star rating', '4.9 star rating', '4.8 star rating']

# %%
# Pull lists into a data frame
freshRoastData = {'Name': names, 
                   'Price': prices,
                   'Rating': ratings,
                   'URL': URLs,
                   'Source': sources}
freshRoast = pd.DataFrame(data=freshRoastData)
freshRoast.head()
# Out:
#                                                 Name   Price           Rating  \
# 0  Unroasted Organic Colombian Sierra Nevada Gree...   $8.95    5 star rating
# 1  Unroasted Organic Guatemala Huehuetenango Gree...   $7.95  5.0 star rating
# 2  Unroasted Organic Bali Blue Moon Green Coffee ...  $10.95  4.7 star rating
# 3          Unroasted Costa Rica Tarrazu Green Coffee   $6.95  4.7 star rating
# 4     Unroasted Organic Mexican Chiapas Green Coffee   $6.95  4.8 star rating
#
#                                                  URL                Source
# 0  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 1  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 2  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 3  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 4  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee

# %%
# Remove the dollar sign in Price
freshRoast['Price'] = freshRoast['Price'].str.replace('$', '')

# Remove extra words in Rating
freshRoast['Rating'] = freshRoast['Rating'].str.replace('star rating', '')

freshRoast.head()
# Out:
#                                                 Name  Price Rating  \
# 0  Unroasted Organic Colombian Sierra Nevada Gree...   8.95     5
# 1  Unroasted Organic Guatemala Huehuetenango Gree...   7.95   5.0
# 2  Unroasted Organic Bali Blue Moon Green Coffee ...  10.95   4.7
# 3          Unroasted Costa Rica Tarrazu Green Coffee   6.95   4.7
# 4     Unroasted Organic Mexican Chiapas Green Coffee   6.95   4.8
#
#                                                  URL                Source
# 0  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 1  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 2  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 3  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee
# 4  https://www.freshroastedcoffee.com/collections...  Fresh Roasted Coffee

# %% [markdown]
# ### Create database connection

# %%
# Configure the database connection
rds_connection_string = "postgres:88653680Dd!@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirm the existing tables
engine.table_names()

# %% [markdown]
# ### Load DataFrames into database

# %%
# Copy and rename DFs for each DF being loaded
df.to_sql(name='coffee', con=engine, if_exists='replace', index=False)

# %% [markdown]
# # Confirm data has been added

# %%
# Read the table data from SQL
pd.read_sql_query('select * from coffee', con=engine).head()
